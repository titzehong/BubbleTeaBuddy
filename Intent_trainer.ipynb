# %% [markdown]
# # Final project: StackOverflow assistant bot
#
# Congratulations on coming this far and solving the programming assignments! In this final project, we will combine everything we have learned about Natural Language Processing to construct a *dialogue chat bot*, which will be able to:
# * answer programming-related questions (using StackOverflow dataset);
# * chit-chat and simulate dialogue on all non programming-related questions.
#
# For a chit-chat mode we will use a pre-trained neural network engine available from [ChatterBot](https://github.com/gunthercox/ChatterBot).
# Those who aim at honor certificates for our course or are just curious, will train their own models for chit-chat.
# ![](https://imgs.xkcd.com/comics/twitter_bot.png)
# ©[xkcd](https://xkcd.com)

# %% [markdown]
# ### Data description
#
# To detect *intent* of users questions we will need two text collections:
# - `tagged_posts.tsv` — StackOverflow posts, tagged with one programming language (*positive samples*).
# - `dialogues.tsv` — dialogue phrases from movie subtitles (*negative samples*).

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

if IN_COLAB:
    ! wget https://raw.githubusercontent.com/hse-aml/natural-language-processing/master/setup_google_colab.py -O setup_google_colab.py
    import setup_google_colab
    setup_google_colab.setup_project()

import sys
sys.path.append("..")
from common.download_utils import download_project_resources

download_project_resources()
# Out:
# HBox(children=(IntProgress(value=0, max=18012894), HTML(value='')))
# Removed incomplete download
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-624a89ebad6c> in <module>()
#      14 from common.download_utils import download_project_resources
#      15
# ---> 16 download_project_resources()
#
# ~/coursera/common/download_utils.py in download_project_resources(force)
#      96         ],
#      97         "data",
# ---> 98         force=force
#      99     )
#
# ~/coursera/common/download_utils.py in sequential_downloader(version, fns, target_dir, force)
#      41     os.makedirs(target_dir, exist_ok=True)
#      42     for fn in fns:
# ---> 43         download_from_github(version, fn, target_dir, force=force)
#      44
#      45
#
# ~/coursera/common/download_utils.py in download_from_github(version, fn, target_dir, force)
#      35         print("File {} is already downloaded.".format(file_path))
#      36         return
# ---> 37     download_file(url, file_path)
#      38
#      39
#
# ~/coursera/common/download_utils.py in download_file(url, file_path)
#      17             bar = tqdm_utils.tqdm_notebook_failsafe(total=total_size, unit='B', unit_scale=True)
#      18             bar.set_description(os.path.split(file_path)[-1])
# ---> 19             for chunk in r.iter_content(32 * 1024):
#      20                 f.write(chunk)
#      21                 bar.update(len(chunk))
#
# /usr/local/lib/python3.5/dist-packages/requests/models.py in generate()
#     743             if hasattr(self.raw, 'stream'):
#     744                 try:
# --> 745                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     746                         yield chunk
#     747                 except ProtocolError as e:
#
# /usr/local/lib/python3.5/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     434         else:
#     435             while not is_fp_closed(self._fp):
# --> 436                 data = self.read(amt=amt, decode_content=decode_content)
#     437
#     438                 if data:
#
# /usr/local/lib/python3.5/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# /usr/lib/python3.5/http/client.py in read(self, amt)
#     446             # Amount is given, implement using readinto
#     447             b = bytearray(amt)
# --> 448             n = self.readinto(b)
#     449             return memoryview(b)[:n].tobytes()
#     450         else:
#
# /usr/lib/python3.5/http/client.py in readinto(self, b)
#     486         # connection, and the user is reading more bytes than will be provided
#     487         # (for example, reading in 1k chunks)
# --> 488         n = self.fp.readinto(b)
#     489         if not n and b:
#     490             # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.5/socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# /usr/lib/python3.5/ssl.py in recv_into(self, buffer, nbytes, flags)
#     927                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     928                   self.__class__)
# --> 929             return self.read(nbytes, buffer)
#     930         else:
#     931             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.5/ssl.py in read(self, len, buffer)
#     789             raise ValueError("Read on closed or unwrapped SSL socket.")
#     790         try:
# --> 791             return self._sslobj.read(len, buffer)
#     792         except SSLError as x:
#     793             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.5/ssl.py in read(self, len, buffer)
#     573         """
#     574         if buffer is not None:
# --> 575             v = self._sslobj.read(len, buffer)
#     576         else:
#     577             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# For those questions, that have programming-related intent, we will proceed as follow predict programming language (only one tag per question allowed here) and rank candidates within the tag using embeddings.
# For the ranking part, you will need:
# - `word_embeddings.tsv` — word embeddings, that you  trained with StarSpace in the 3rd assignment. It's not a problem if you didn't do it, because we can offer an alternative solution for you.

# %% [markdown]
# As a result of this notebook, you should obtain the following new objects that you will then use in the running bot:
#
# - `intent_recognizer.pkl` — intent recognition model;
# - `tag_classifier.pkl` — programming language classification model;
# - `tfidf_vectorizer.pkl` — vectorizer used during training;
# - `thread_embeddings_by_tags` — folder with thread embeddings, arranged by tags.

# %% [markdown]
# Some functions will be reused by this notebook and the scripts, so we put them into *utils.py* file. Don't forget to open it and fill in the gaps!

# %%
from utils import *
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Part I. Intent and language recognition

# %% [markdown]
# We want to write a bot, which will not only **answer programming-related questions**, but also will be able to **maintain a dialogue**. We would also like to detect the *intent* of the user from the question (we could have had a 'Question answering mode' check-box in the bot, but it wouldn't fun at all, would it?). So the first thing we need to do is to **distinguish programming-related questions from general ones**.
#
# It would also be good to predict which programming language a particular question referees to. By doing so, we will speed up question search by a factor of the number of languages (10 here), and exercise our *text classification* skill a bit. :)

# %%
import numpy as np
import pandas as pd
import pickle
import re

from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ### Data preparation

# %% [markdown]
# In the first assignment (Predict tags on StackOverflow with linear models), you have already learnt how to preprocess texts and do TF-IDF tranformations. Reuse your code here. In addition, you will also need to [dump](https://docs.python.org/3/library/pickle.html#pickle.dump) the TF-IDF vectorizer with pickle to use it later in the running bot.

# %% [markdown]
# Firstly load the data

# %%
from random import sample

a=pd.read_csv('movie_lines.tsv',header=None)

def cleaner(x):
    out = x.split('\t')
    return out[-1]

lol = []
for l in a.values:
    lol.append(cleaner(l.item()))

# %%
lol1 = sample(lol,2000)

# %%
lol1
# Out:
# ['Good swell.',
#  "We're not watching the sea.",
#  'I got a call to this apartment report of a disturbance --',
#  'I thought you said Krueger burned to death.',
#  "It ain't always a blessing.  My brother here?",
#  "You're not like him at all.  I don't know exactly what's going on around here lately but don't make me start worrying about you.",
#  "You don't even want to touch me.",
#  "I'm sure of it. Just as I'm sure there's a wish for Shangri-La in everyone's heart. I have never seen the outside world. But I understand there are millions and millions of people who are supposed to be mean and greedy. Yet I just know that secretly they are all hoping to find a garden spot where there is peace and security where there's beauty and comfort where they wouldn't have to be mean and greedy. Oh I just wish the whole world might come to this valley.",
#  "C'mon man...",
#  'Sign here please.',
#  'Ich weiss alles.',
#  "Oh sure it was all mean old Marcel's idea. Give me a break! We didn't tell you because it's a wild goose chase! Not to mention disgusting. Look...",
#  "You know what?  I think you got Schwarzkopf.  You did!  You got the General right in the ass.  Now that's good shooting.",
#  "I don't know if that's such a--",
#  'Typical male.',
#  'It also says here -- that you are alert astute and quite imaginative --',
#  'Yeah.  Well...I think it is important for you too.  Sit down.',
#  "You'll feel better tomorrow.",
#  'David.',
#  'Why do hate the Grey Hair Magua?',
#  'No.',
#  "Right now you're in no position to ask questions!  And your snide remarks---",
#  "I didn't realize. Yeah you do look a little pale. How soon will you be ready? A week?",
#  "Face it we're the men for the job. Besides if someone is really chasing you the best way to avoid them is to keep moving ...and FIND THE GODDAMN PEM.",
#  'You know her?',
#  "You'd like to see a nuclear holocaust?",
#  '- guilty.',
#  "She does at that.  I knew when I married her she was a free spirit. A woman with her looks and a man my age; what was I to expect?  But you see a woman like that in a town like this and you don't think you do. So I married her.  What are you to do eh?  Women.",
#  "It's gonna work Dad.  We're gonna stop him.",
#  "I don't know what you expected to find Matthews. There's nothing wrong with the antigens nothing to indicate an unusual death...",
#  'Make her easy John. Watch her.',
#  "I'll call you right back.",
#  "I'm here aren't I?",
#  'Can you see?',
#  "Don't go.  Don't go in that warehouse...",
#  "No it's not Don.",
#  'What?  What is it?',
#  "And she could do a hell of a barbie to boot! Belt up. You'll find all the parts you need up there.",
#  'Plato!',
#  'That\'s right.  Max it seems has two unique gifts -- a capacity for anonymity and for corrupting susceptible agents. This time he\'s gotten to someone on the inside - he\'s put himself in a position to buy our NOC list. An operation he referred to as "Job 314".  The job he thought Golitsyn was doing tonight.',
#  "You won't dare to interfere with me here. This is still unoccupied France. Any violation of neutrality would reflect on Captain Renault.",
#  "It'll be okay baby I'll hold your hand.",
#  "Sal if you want me to deliver any faster get me a jet rocket or something cuz I can't run with pizzas all the cheese ends up on one side and shit.",
#  'What is this thing?  A fighter?',
#  'Who is...',
#  'Sir please accept my commission from Congress... and...  You must see this portrait of my beautiful wife Adrienne we had the most perfect little baby girl just before I left.  Her name is Henriette...',
#  'What about the moon?',
#  'Thank you Jennyhaydn. You are good. I must go alone now.',
#  'Leave that alone!',
#  'And do you also say Fro dereck?',
#  "Goddamn it I ask you a question you better answer it or I'm gonna blast a hole in ya!",
#  "Don't you really want to know? Was Jake my Daddy? Was I fucking my own Daddy? Don't you want to know that?",
#  "Shit Lenny. What's happened to you! We've gotta get help!",
#  'Never mind.',
#  "That's what I said it's so - it's too absurd!",
#  'No... I...',
#  "I didn't know where else to keep it.  Where would you?",
#  'You going to have the time?',
#  "As long as it's on their terms. If your work and your private life don't correspond to their specifications you're labelled a dangerous agitator -- with no recourse whatsoever.",
#  "Again I don't mean to be annoying with my questions.  But if it <u>is</u> a crocodile which I don't think it is.  And if they <u>do</u> charge these baby hatchling sounds...  why exactly would you want to be underwater at the time?  With you it makes sense.",
#  'Poker!',
#  "That's right. -- Rubbers too I hope? A man ought to be prepared for any emergency.",
#  'Yes.',
#  "No. I -- I guess I'm not what you expected.",
#  '... interview every employee support staff associates partners. Did <u>any</u> of them know Andy was sick? <u>How</u> did they know? Did he tell them? Did they notice something was wrong with his appearance? None of this information got to the managing partners. We know that. Make sure everyone else does too... And Beckett: I want to know everything about his personal life. Did he frequent those pathetic bars on Camac Street?',
#  '-- I was just trying to finish some work!',
#  'Did you just call me a fuck-ass?',
#  "Then you're only a hundred-forty- five in the hole.  Now why don't you just take your Visa Express Silver Card call Karl Malden and have him send you the money lickity split.",
#  'Good night Josephine.',
#  'Never said a truer word.',
#  "Not everything... Do you think I care?  I'm a free man again.  Riches don't make a man rich they only make him busier...",
#  'Sweet.',
#  "You don't count Saturday.",
#  'Huh.. .Hello?',
#  "I guess that's where everyone meets him.",
#  "I'm not sleepy. I want to look at my flower.",
#  "There's no transportation anyway this time of night.",
#  "Oh it's... I wanted to tell you that if you'd like you being so busy I could take Grace to her therapy exercises for you. I have to go in once a week for shopping anyway.",
#  'Yeah.  Some of them...yeah some of them are very big.',
#  "Oh I'll be fine.  Got my chair got my window I'm great.",
#  'Maybe we should call the Coast Guard.',
#  "All right thanks to her and thanks to this case of epizootics you are getting another chance.  But don't try my patience again. We have growing children in this house. Do you understand me?",
#  'Hunt with Vince?',
#  'Not exactly.',
#  'You mean you cough up hairballs all over the rug?',
#  'Where are the papers?',
#  "We got the Sphere but the Commander's down there with a bunch of cannibals!  Teb reset the pod we're going back.",
#  'What? When? When did all this shit happen?',
#  "He's an entomologist!  I thought it was very unique.",
#  'I think to myself  what problems could she possibly have?',
#  "But my mother says I mustn't accept gifts from strangers.",
#  'Everything.',
#  'Swear to god.',
#  'You want to fuck her?',
#  'What now sir?',
#  "It's on West Broadway. We can walk.",
#  "Yep we had 'em in orange crates all over. It was Daddy's dream. He was goin' to get rich raisin' rabbits. It was what killed Daddy. He didn't drown hisself till a long time later after Momma and Lunette died of typhoid but it was them rabbits what killed him.",
#  'Based on what?  You never even see him.',
#  'Twist you know this guy?',
#  'Well er -- it looked a little cloudy this morning.',
#  "Look it was a screw-up alright? They weren't supposed to find anything.  We thought that camp was empty.",
#  'It used to make me laugh but.',
#  'Liza?',
#  'Excuse me Professor Lambeau?',
#  "You don't look so good.",
#  'Not at all.',
#  'Now Thelma that is not...',
#  'You was right to change your mind Kid.',
#  'Under the mat? ',
#  "Well it is to me.  Will you give her a message?  I'd like her to have a little supper with me on my yacht after the show tonight.",
#  "I'm an orderly not a bleeding psychiatrist! I push things about but I've little say what happens to them.",
#  "I'll spend the night here and get back first thing in the morning.",
#  'Boy! Did you see the way Mama whopped that deputy with her shoe? Knocked the gun right out ...',
#  "It was a different time son.  And you're a better man than that.",
#  "And who accused him? Diamond Louis! One of the worst crooks in town! Why don't you arrest Louis instead of innocent people that he frames?",
#  'Yes he looks like a comrade!',
#  "Just one little thing. How come you were so sure Manfredi and Johnson wouldn't get out of the forest?",
#  'I must do this for Paul but what of my unborn child?',
#  'You see you knew the answer all the time General.',
#  "Yes. Haven't you thought about it at all? Seems to me you could make some girl wonderfully happy.",
#  'He is now.',
#  'You called me I knew they were there so what do I need these for?',
#  'Remember when you asked me what my idea of "normal" was?',
#  "Don't worry it's all over now. Thank God for the decent people.",
#  'Drugs begin pouring out of America into every other country in the world. Canada is completely overwhelmed.',
#  "Mikey's the big winner.",
#  'Yeah. Thanks.',
#  'It is a courier Captain. Grade One priority. Non-belligerency confirmed.',
#  "  Oh we're screwed Night...",
#  'Hell yeah. I love. I love sex.',
#  "Beat your butt you don't lemme think!",
#  "Jesus. I'm sorry.",
#  'Very clumsy very clumsy.  I\x92d have found it in a minute.',
#  'I know. He started it Fall semester.',
#  'I have a job.',
#  'How neat.  How keen.',
#  "Kill a few people they call you a murderer.  When you kill millions you're called a conqueror.  Go figure.  Move on Tucker time is short.",
#  "You think I'd really drink that?",
#  "What are you an idiot? Didn't you see the red light was on?",
#  "That's all right.",
#  'Indy! Henry! Follow met I know the way!  Haaa!',
#  "It was nothing.  We're not ... He just makes me laugh.  When was the last time we laughed?  Any of us?",
#  'Where did you learn that word?',
#  'In other words scurvy.',
#  'Farley!',
#  'What do you know about the ear? Anything?',
#  'You know he\x92d have had him killed don\x92t you? Does a conscience still burn somewhere inside your sore mind Deborah? Or is it just cold expediency? Could the boy perhaps come in useful when and if the day ever comes for you to face up to the man you married?',
#  'Who... Who is that?',
#  'The pigs are gonna start flooding us with dope. Huey wants us to stop them.',
#  "Did you get smashed or what? You have to eat if you're drinking. And not just those little salads.",
#  '"Each day is a little life.  Every waking and rising a little birth every fresh morning a little youth every going to rest and sleep a little death."',
#  "And you're still trying to get me into bed.",
#  "God if he doesn't come back --",
#  'You got it. Berkeley?',
#  'I like my job.',
#  'Children often have trouble adjusting to a new school.',
#  "But why?  I can't understand how I could just completely--",
#  'Thank Christ for that.',
#  "After this job I'm looking forward to being alone for a while.",
#  'You look good.',
#  'How am I supposed to know?',
#  'And then what happened?',
#  'We will answer and present <U>proof</U> of our answer when it is ready!',
#  "It's a quality that might come in handy for a commercial sometime. _ 69.",
#  "I picked up my ticket.  I'm leaving in the morning Jez.",
#  "Buddy buddy when ya gonna realize it's big game hunters that bag the elephants not retail brokers. I heard this story about Gekko... he was on the phone 30 seconds after the Challenger blew up selling NASA stocks short.",
#  "Passport visas - you know the drill. We'll work the exfiltration thru Canada debrief you at Langley.  Throw the Prague police a bone you know toss them a few suspects.  Follow me?",
#  'Professor?',
#  "You're not resting well are you? I know -- it's that music.  You need your sleep. Is there anything else you want?",
#  'Because I want you to tell me.',
#  "Too bad they don't give an award for talkin'... You'd win first prize. Especially with those tits.",
#  'Might we watch too?',
#  'What?',
#  "My father told me not to be afraid. He'd always be there for me.",
#  "Death didn't improve your sense of humor.",
#  "What are you doin' in there?",
#  'Madness?',
#  'No.',
#  'Hey Kit where do I go for the clothes?  Good stuff on <u>him</u>.',
#  'You got a round figure on it?',
#  "Well the paper'll have to learn to do without me. And so will you. It just didn't work out Walter.",
#  'Fourth floor West wing but stay with your class.',
#  'Now this is just a signature card.',
#  'Not at all I enjoyed --',
#  'Continue.',
#  'Yeah.',
#  'One lonely terrifying sea snake.',
#  'Jim West.',
#  "See here this is us.  All the way round here Fiji.  You can't get any further away before you start coming back.  Y'know there are still islands in Fiji where no human has ever set foot.",
#  'Gus this --',
#  "Yes adulation is a cross to bear. God knows <u>I</u> know.  But someone's got to supplant our standing-in- the-way-of-progress Mayor and don't deny it Mr. Cobblepot you've got the magic!",
#  "Come on man.  There's love and there's ...",
#  'They turn their back on it.  Takes away its energy and it disappears.',
#  "This I don't know maybe you can trade it for something.",
#  'Absolutely.',
#  'Hello?',
#  "I'M LOOKING FOR LOVE",
#  'No not yet Agnes very soon but not yet. How did the baby get into you?',
#  "I made Sir William Cosgrove's acquaintance as usual at the play- table.  One could not but admire the spirit and gallantry with which he pursued his favorite pastime; for though worn out with gout and a myriad of diseases a cripple wheeled about in a chair and suffering pangs of agony yet you would see him every morning and every evening at his post behind the delightful green cloth.",
#  'Oh my darling. Oh my sweetheart.',
#  "Only this isn't a bail bond Max.",
#  "But Hollywood. You mustn't stay there.",
#  "There's nothing to see here. He sleeps... we record it. That's all that happens.",
#  "I can't help it.  He gives me the creeps... I mean why was Suzie so scared of him?  She's not that way.  I think he did something...",
#  "Hang on.  There's gotta be something on this guy.    Did you contact the Alliance?  Do they have anything?",
#  'Clark did you notice anything strange about that dog?  Just anything at all?  Any little thing?',
#  "Nothing for him! He's being repressed.",
#  'Move quickly. We are coming for you. We are in the Fortress.',
#  "We don't have the time to bring someone new up to speed. Besides...  You've already impressed everyone you need to haven't you?",
#  'It excites him. Most serial killers keep some sort of trophies.',
#  "Charenton has changed; it's not safe for you here.",
#  'You wanna go on a date with me?',
#  'And this Butterfield guy--',
#  'Yeah. You must come again.',
#  "That's Charlie.  My best friend. He's into beef analogies partly because he's a butcher's son and partly because well he's just into beef analogies. What can I say? He's also a photographer...",
#  "But it doesn't work that way. A major decision was handed down by the Appellate Court in 1969--in the case of Haskins vs. Haskins.",
#  "Too risky. We don't need to get pulled over because of a stolen car.",
#  'If a young woman a stenographer -- etc.',
#  'You starting that again?',
#  'Where?',
#  "And of course I accept.  I'm flattered.  And I want you to know I work for only one president at a time.",
#  'You have forgotten my last name?',
#  'Oh!',
#  'How would you know?',
#  "She's dead?",
#  "Sort of like Benedict Arnold coming back to George Washington's cabinet.",
#  'Well?',
#  'Dashes and Dots.  And those dots spell out a message in the Morse Code. And that message is "Courage Mom..."  And he got the message through. "Courage.  Mom..."  Well to the Family of William A. Schumann to the Men and Women of Unit 303 to my fellow citizens <u>I</u> say "courage."  I have informed the Albanian government and I inform <u>you</u> that we will not rest until the safe return of Sergeant Schwn&nn.  I\'m told his unit mates gave him the nickname "Old Shoe."  Ladies and Gentleman we will not <u>treat</u> him like an Old Shoe we...',
#  'Tell us about him.',
#  "It's a rubbing Dad made of the Grail Tablet.",
#  'Sang? His name is a past tense?',
#  "Why don't we start with that next week?",
#  'Jefferies?',
#  'They gave you a pardon man.  Whatdaya want?',
#  'How many girls did you molest?',
#  'Saw you at the mall yesterday.',
#  'Yeah it was all just an accident.',
#  "Well it's just that I would think that the woman who is the real non- imitation Catwoman would be pretty angry at some little amateur minx stealing the whole whip idea. Really angry.",
#  "You got it Dad.  I'll call you if I have a problem.",
#  "Think I got 'em?",
#  'But you did and have... And now people are dead.  Did Sparazza become more valuable than Israel... and did you make another deal?',
#  "When they find out what it's carrying they may not be so interested in what's legal.",
#  'Howard give him the keys...',
#  "Guys I don't mean to be rude but I only have eleven hours and fifty-three minutes to...",
#  "Anthony Red stay with the guns!  Coma you cover the cannons!  Joe Theo come with us!  Earl you get on the radio! We're gonna fight these fuckers.",
#  'Yes darling',
#  'Dad!',
#  'Of course not... but... when I was a child... I remember a dream.... it was as if the whole sky was blue...',
#  'Mr. Preysing has too scrupulous a regard for certainties...',
#  'I run a temp agency.',
#  'STAY WITH HIM! TIGHTEN YOUR TURN!',
#  'The cathedral is coming along nicely.',
#  "This is stupid.  It'd be just too easy.",
#  "That's how you get things right is to always try and never give up.  Huh Mom?",
#  'Camels same as me... Guess both my mama and my daddy died of smoke or alcohol related illness.',
#  'My dear sir I would gladly change rooms with you.',
#  'Go fuck yourself.',
#  'Sure.',
#  "You're not going to use it are you?",
#  'She meant nothing to you either until I told you she died.',
#  'Oh no.',
#  "The mines the wires there's a trick. Some explode if you stretch the wires some if you cut them.",
#  "Yes I know dear but Mrs. Burke had her baby yesterday. Nine pounds! And there wasn't a thing in the house\x97and then this morning the Community Chest lady came around and\x97",
#  'Is it set?',
#  'What "Q-man" did I forget to kiss your ass like everybody else?',
#  'Igor -- the clock!  Hurry!',
#  "Why well I think we've we both don't know...what do you mean?",
#  'What happened to Bella?',
#  "Who would've thought he was capable of such atrocities?!",
#  "Then he stashed it somewhere or he has an accomplice. We'll release him until his indictment keep tight surveillance and see if he leads us to your disc.",
#  'Sleep with me and the secrets of the West are yours.',
#  'Both hands on your lap.',
#  "Really? That's interesting.  Not great?",
#  'Since last night. I was pleased to see you.',
#  'Lock the fucking doors.',
#  "Dr. Wigand you do understand what could happen don't you?",
#  "Mister Washington why don't we get a good head start on the day by shaving Mister Bromden and see if we can't avoid a disturbance.",
#  "Don't tell me. Crest would be stained with loserness.",
#  'Unwelcome.',
#  'Can you even imagine?  Who the hell would go to this a bastion of commercial excess?',
#  "The tighter you squeeze the harder he'll try to break free.",
#  "Well that's my poor upbringing. I didn't go to no private school. I haven't got no class. I want to live with a writer. Not a fucking croupier. I don't even know what the word means. Croupier.",
#  'But you refused me Dorothy.',
#  "Mine's J.F. Sebastian.",
#  'First things is don\'t say "What\'s going on?" Everybody knows what\'s going on. I come into this situation I say  "I\'m glad to see nobody\'s hurt. That\'s good. I\'m here to help you."  Second: You hesitated. Don\'t hesitate. If you\'re thinking talk while you\'re thinking or else he\'s going to think you\'re plotting. Which you are. If he thinks you\'re plotting you\'re going to make him nervous. You don\'t want him nervous. Got that?',
#  '... Deborah Ann Kaye ...',
#  "So they're airing this tonight?",
#  'When?',
#  'Ya find the work interesting do ya?',
#  'So...  That your first time?',
#  "You don't need to do that.",
#  "C'mon c'mon that's it...",
#  'Did I say that?',
#  'Yes Captain?',
#  'She was talking about... a "harvest of blood"...',
#  'Dennis?  I want you to release those people.',
#  'Goodbye.',
#  'No I think your mother her illness --',
#  'Congratulations Field Agent Kensington!',
#  "I know you don't. That's the point. I'll say no more.",
#  "Karl? Did you put this in Regan's bedroom?",
#  "Let's go --  We got to get away from this phone.",
#  'Join the party fellas.',
#  'What did you do while the sergeant was killing your son?',
#  "You're in the Nexus.",
#  "Unbelievably sexy. Yes you are. Because... you know what you are? You're-you're polymorphously perverse.",
#  'Where do you get these questions?',
#  "What's this?",
#  "Pleased to meet you ... Hi bow's it going? Pleased to meet you! Hi Carl Denham ... How's it going?",
#  'Really do you think so really?',
#  "Whom you've seen twice in a year? Mrs. Kramer your ex-husband wasn't he the longest personal relationship in your life?",
#  "Careful with that one. He won't tell me anything but I know there's something strange going on over at the lanes. If you ask me I'd say the old fart wants to die.",
#  "Don't needle me Elliot. Tell me how bad you feel. We're suppose to feel bad together. This is what friends do.",
#  'Yeah. Yeah.',
#  "Are you really Carson Dyle's brother?",
#  'Why would someone do that?',
#  'Goodbye.',
#  "As a matter of fact I'm out of cash myself.",
#  'Do you want to tell me what you found?',
#  "You're my best friend.",
#  'Well I can certainly understand why you left him.',
#  'Ecentus stultorum magister.',
#  'Hurry the fuck up!',
#  'Look maybe I\x92m not as good a consigliere as you are but you have to trust me on this one.  A little flirtation\x92s harmless but you\x92re playing with fire here.  The Fidelity Bank and Trust is a tough creditor.  You make a deposit somewhere else they close your account forever.',
#  "Look at that sky.  It's so big.",
#  "It's always how you would do it. This is my version.",
#  "Slip up and change into a skirt else he'll create something terrible. Don't you want to make a good impression on your first day?",
#  "Joan call a cop!  We'll arrest this kid for larceny!",
#  'Are you sure?  Jack -- this is not something you have to do.',
#  'I have the rest of my life to find out.',
#  "I'm sorry I got you into this.",
#  'Rod says the sweetest things.',
#  "You don't even remember...",
#  'I know be still.',
#  "Sheriff just radioed me. I'm gonna check out a possible lead. Thought you might like to join me.",
#  "Momma I'm all right I'm fine really I am.",
#  'They are incapable of organized warfare!',
#  'Are you staying at the hotel?',
#  "Look Jerry you're not sellin' me a damn car. It's my show here.  That's that.",
#  "Because she didn't know she was going on a trip -- and where she was going she wouldn't need a handbag.",
#  "I thought I'd help out.",
#  'So lemme see it.',
#  "Yeah I said I - let the bullshit blow over for a while so I can run the casino. Anything goes wrong with the casino it's my ass. It's not yours it's my ass.",
#  'No snacking between meals!  Off you go!  Now -- what were we saying?',
#  "He can't kill you --",
#  "I don't think so. She'll want Larry first.",
#  "Then why's the company hanging tough? They've signed contracts with other locals -- why not this one?",
#  "I'm not having any more children. After Amado I had some complications-- I can't get pregnant again if that's what the rule is about--",
#  "Mountain grass. It's good too. Here have some. I've read of people lasting thirty days on this stuff.",
#  'I did go.  Just back.  Reef these are a couple of our passengers - Sir Ian Hunt and Dr. Clifford Kent.  My exec Commander Richard Holloway.',
#  'Duck here they come.',
#  'In real life when does he hit you?',
#  "Just remember - you're a target.  Don't you think Vince has a T.V.?",
#  'Gently.',
#  'Yeah.',
#  "You don't like me?",
#  "It takes hours to get a drink around here.  There's only one waitress.",
#  "Hey fella let's get this done...",
#  'Still clear.',
#  'All right then...',
#  'Go!',
#  'Not on him Chief.',
#  "I said I had no family -- I didn't say I had an empty apartment.",
#  'Yeah I know.',
#  "I said I wouldn't.",
#  "If I weren't married?",
#  "We're half a million off.",
#  "Yes. I am obviously not standing out in people's minds at the robberies.",
#  'Maker?... Maker is the key word... the tooth of the worm? That was close...  Did you think that I knowing the mysteries of the Great Mother would not know the maker?',
#  "A lot of tape and a little patience make all the difference.  By the way how's Fred Adkins your old partner?",
#  'Yeah ye-- I -- uh there were earlier there was that guy Carrut--',
#  'That Harry was dead before you got him to that statue.',
#  "There's nothing like weightless sleep for a complete rest.",
#  "This is something that is never going to end.  You can never work in the business again with this contract because he will find you. To survive you have to go into deep hiding.  And that's going to take money a lot of money.",
#  "I'm a Christian.",
#  'Hildy!',
#  'When you have found the shrubbery place the shrubbery here beside this shrubbery ... only slightly higher so you get a two-level effect with a path through the middle.',
#  'Thais.',
#  'I saw how it has to be.',
#  'Eleven.',
#  'Do you really think so?',
#  "Oh you don't have to worry about that.",
#  'Jesus Patrick!',
#  'For the time being I imagine that must do.',
#  "Listen this ain't about us! It's about a thirteen year old girl. She's not gonna make it. Unless we do something.",
#  'Why not?',
#  "It's up to you. Air Patagonia. New outfit: via Caracas and Bogot . No catering. Four hundred and eleven pounds. Four one one. Good value but refueling at Bogot  is variable.",
#  'The place has already be combed. Forensics pulled over a hundred sets of prints inside.',
#  'You keep it nice.  Can I ask you is this-is this a sandwich?',
#  "Now quit Bobby. You said you're goin' a help me pick a song.",
#  '...Who are you?',
#  'Sean!  Listen!  Listen to me Sean.',
#  "So what'd you think?",
#  "Good.  Because I'm fed up.",
#  'So you were unhappy?',
#  'What happened to him? What happened to Creasy?',
#  "You've got to tell me what she said.",
#  'That\'s what I\'m afraid of. "Any time -- any place -- anywhere!"',
#  'How could I be?  The mainland has been found.  Exactly as I said it would.',
#  'All the time. We all live in Southie. I live with three of them now.',
#  'What do you want for it?  Two thousand? Three thousand?',
#  "But Sidney darling the man must be out of his mind - it was only eleven o'clock in the morning!",
#  'I know.  And nobody can make him.',
#  '1002.',
#  "You're a little harsh on Todd. You're a little harsh on everybody. I know                         ] you like to think of yourself as                            ] the Anti-Oberon but man you're                            ] getting just as spooky. What was                            ] that speech in there?  Does Camp really                     ] have to be a revolutionary act?  Can't                      ] the children at their own pace                            ] discover...                                                 ] ] WICHITA                                            ] Yeah okay I was a little out of                           ] hand but come on you got to give me Todd.  Don't get me wrong I've learned to love the little Piggy but Todd is the most invincible loser I've ever come across. His greatest talent is lack thereof. No matter                           ] what the category bet against him                          ] and win.                                                    ]",
#  'Yeah.  Least I think so.  Twenty- six years this March.',
#  "You're talking about my lady.",
#  'Camelot ...',
#  'I have ideas.',
#  "He's not coming.",
#  'Really?  Then... what is your rebuttal to those romantic poets claiming proof of magic in a rose at full bloom or even in a teardrop?',
#  'Good boy Schnoz. Daddy loves you.',
#  'Monsieur Blaine I wonder if I could talk to you?',
#  "Yeah well...couldn't be helped.",
#  'No! Arrgh!',
#  'Conrad has the phone number. Conrad where is he?',
#  'Right after we played backgammon.',
#  "Nothing to resolve Ian.  Let's get a drink.",
#  'You never told us you grew up on a farm.',
#  'Now release the brake. And slide the stick into first gear.',
#  "No class grifter woulda' done it that's all.",
#  "Eleven o'clock! ",
#  "That's right. She will get fired. In fact I want you to send her back to Paris.",
#  'Look you heard what those hookers said. They were supposed to go to a bachelor party.',
#  "I understand he's hardly had a life of his own since he left the show.  How did you convince him--was it the opportunity to be close to Truman again?",
#  "INT. LONG'S CAR - NIGHT.",
#  "It's a lie!",
#  'How come you\x92re alive? Child traffickers usually achieve what they set out to do.  What am I really looking at here huh?  Are you really not just a lousy private eye? Am I really looking at some kind of cunning dispenser of justice in disguise?',
#  "It'll be ready in a minute.",
#  'What would you say that was supposed to mean?',
#  'He needed money?  For the operation for you?',
#  'Teresa.',
#  "See.  Dry.  It's in the delivery.",
#  'Have now.',
#  'Red Deer Table Ray.',
#  "She doesn't want me here.  With you.  In this house.",
#  "Aren't I like the chosen one?  The one and only?  The Grand High Poobah and doesn't that mean you have to be nice to me?  Like ever?",
#  'Try not to think of that Mrs. Brenner.',
#  'Lieutenant.',
#  'Yes. To all of us. The closer we come to an atmosphere with only one sun - a yellow sun - the more our molecular density gives us unlimited powers!',
#  'Tuesday.',
#  "You've been playing with it?",
#  "What I'm tellin' you. Girl gotta get dick or she go crazy.",
#  "Let's just call it square.",
#  'We did it.',
#  "What is it George?  Because I have to get home.  I've got a parole officer waiting for me.",
#  "That'sa Lucille you mullet head! Any girl so innocent and built like that gotta be named Lucille.",
#  'You little sleaze bag!',
#  'What was she doing?',
#  "Good...Another is you're trying to make it all about sex and heat and nothing else.",
#  'A hundred and one next month.',
#  'Do you still go to church?',
#  'Start over.',
#  'Ah what else indeed? Let me put it another way: how thick would a piece of your plexiglass need to be at 60 feet by 10 feet to withstand the pressure of 18000 cubic feet of water?',
#  'Hi babe.',
#  'Sixth is faster.',
#  "He's the one who wants you.",
#  'Relax Mulvihill glad to see you.  Do you know Claude Mulvihill here?',
#  "I'm so sorry.",
#  "Claire Claire Claire if you're not dead he's going to assume you're with me.",
#  'Huh?',
#  "The picture was fine! It's what that knuckle-headed dame wrote underneath! Of all the irresponsible... Amy take this down: Dear Miss Archer. I call you 'Miss' because you seem to have 'missed' the boat completely on this one! How on earth would you know whether I'm an imbecile when you don't even have the guts to come in here and interview me man to man! No change 'guts' to 'courage.' No make it 'common decency.' These wild speculations about my intelligence --",
#  '-- and I was wondering if I could buy you a drink or something --',
#  "Mr. Thatcher is going to take you on a trip with him tonight Charles. You'll be leaving on Number Ten.",
#  "Nah It probably won't turn up anything. I'm just gonna talk to him.",
#  'All right son -- if it helps.',
#  'Hey is that really necessary?',
#  "Why are you saying that? [Beat] We don't have long do we?",
#  "Send him? Ma I can't. it's -- just come out here. Please I --",
#  "She's with me.",
#  'This is a good letter Dad.',
#  "You should a joined us Everett. It couldn't a hurt none.",
#  "You -- Listen: you said to me 'if not now when...'",
#  'Champagne please.',
#  'Hi Dad.  Dad this is Jessica.',
#  "I can't tell her.  She's called off her wedding.  She'll never speak to me again.",
#  'Okay. I promise.',
#  'It was the first time somebody ever saw the real me the me that nobody else knows.',
#  'You take care of your family?',
#  "How did you get in here? You're under age.",
#  'Fuck you bitch.',
#  'Cozy Girl in front by a neck... Now a head...',
#  "They don't count.",
#  "So what's your beef pal?",
#  "Shhhh.  Tim I'm right here below you.  Easy catch. One two three.  You count it yourself.  One two three - -",
#  "More nerve than the doctor I must admit.  He hasn't been home for two days.  Has he suddenly lost interest in sleep and color television--and the violin?",
#  'You got us into this mess.',
#  'What about the law?',
#  '"The Dante."',
#  "I know how responsible caring adults parent children.  I'm bribe 'em.  But 'em a dog or something.  Maybe a Doberman.",
#  "Yeah y'ain't heard the punchline yet and before I get to it one more thing I heard little curious should probably bring it up... Primo wants Israel's heart. The actual thing the organ.",
#  'What? You are crazy!',
#  'He did?',
#  'What is it?',
#  'Best way I know to get ink on your hands.',
#  'Heather what is it?',
#  'Not anymore.',
#  'Who?',
#  "Oh well it's... it's not all music you see Missus. It's just the 9th.",
#  "It is called 'The Hawaiian Blue' and there are only seven left. In 1894 the owner of one was murdered by a rival collector who was obsessed to own it.",
#  "It is <u>not</u> your company.  It's a public company.  And I <u>am</u> going to acquire it.  Either I buy from the other stock holders or I buy from you.",
#  "...It's -- Milo isn't it?",
#  "It's a little late for that.",
#  'Yeow!',
#  'Wait a minute. You want to look at fucking penguins now?',
#  "He don't look wise.",
#  'There might have been a word or two that slipped by.  Maybe you could clarify it for me just to be absolutely sure.',
#  'So what do we do for money when we get to New Orleans?',
#  'So do you.',
#  'Mm-hm?',
#  "Calculated risk.  Only we happen to know J.J. that you like me.  I'm your star pupil -- I reflect back to you your own talent.",
#  'ROOAAAARR!!!',
#  "That doesn't make me feel better! Why are you being like this?",
#  'What an asshole.',
#  '... and so and so the doctor says "If this is the thermometer then where\'d I leave the pen?"  You\'re not... you don\'t think that\'s funny?  George work with me I always get a laugh with that one. Look if the doctor\'s got the thermometer in his hand then where\'s his pen gotta be?',
#  'He is so sweet.',
#  'Not really.',
#  "Look I don't know where Mr. Strader might be.  He comes and he goes.",
#  "Now why don't you let these gentlemen pass? Don't you know who's in that car?",
#  "You stick around I'll pull the memo for you.  I'm busy now...",
#  'To what?',
#  'It could be fun.',
#  'It does me good to see you.',
#  'Of course I do!',
#  "I can't!",
#  "He is sick ma'am.",
#  'My advice?  Hop on over to Reno get yourself a quickie divorce.',
#  "I don't know if she'd want me to tell you that Grady.",
#  'I heard that!',
#  "I don't want it.",
#  "Jesus baby you're so full of talk! Well you ain't never really been a nigger have you - livin' like that in your father's house! So just shut your mouth.",
#  "All right ... let's go.",
#  'I should have told you why I broke up with you. I was a coward. You deserve to know.',
#  "I'll get a Dewars rocks... ",
#  'I admire you.',
#  'Well Alexander as a fellow scientist I know you have a thousand questions --',
#  'Again I am the author of the definitive book on the Woodsboro murders.!  What about you?',
#  "Well they didn't think too much of 'em in Paree.",
#  "I don't kill nobody without him. ",
#  'Certified eh? Who is it -- your milkman?',
#  "She thinks you're with Simone.",
#  "I'm afraid not. I promised to have a drink with him -- he's been calling me all week --",
#  'Are you licensed to broadcast buddy?',
#  "I'm telling ya it wasn't that soon. They didn't let their presence be known until after Mr. Blonde went off. I'm not sayin' they weren't there I'm sayin' they were there. But they didn't move in till Mr. Blonde became a madman. That's how I know we were set up. You can see that can't you Mr. White?",
#  'Does that still go?',
#  "Dennis won't let me go to the desk.  He makes me sit on the floor.",
#  'Listen to me.',
#  'Dynamite.',
#  'What did he say?',
#  "You crazy come up <u>here</u>?  It's fuckin one degree outside.",
#  'Florist?',
#  "There's something about the spring that's just cool.  Like the smell of fresh rain or something.",
#  'But this is not a matter which can be settled tonight surely?',
#  "You got no reason to hit me.  I'm getting tired of you and Jaeger pushing me around.",
#  'I...',
#  "That's all talk.  He's got nothing on us.  He let you kill Jake.",
#  "It isn't cheap. It's nice.",
#  "It's not too late to show her you're sorry.",
#  "I don't know!  Andy... you need to look inside: Who are you trying to entertain?  The audience... or yourself?",
#  "Because I'm the one who's single.",
#  'It is. Honestly.',
#  'I said SIT DOWN.  Who do you work for?',
#  "I'm totally serious!",
#  'I care . . . your father cares . . . we want you to have a good education.',
#  "He's going to be in jail for a long time.",
#  "Oh don't worry about that.",
#  "Best not bitch up. Wind up someone's luggage that way.",
#  'Hello?',
#  'Sorry about last night.',
#  '',
#  'And this?  Some of their handiwork?',
#  'Got it.',
#  'Hey -- shut up okay?',
#  "Not tonight you can't. Want to walk back?--or you want me to whistle up some help and take you back?",
#  "Can you bear it? We hear you're a friend of Freddie's -- he has I hate Opera tattooed on his chest.",
#  "You know that's probably not the best idea. I'll just wait to see them in the store.",
#  'He looks wonderful Jackson...',
#  'I want to see him tomorrow Clyde.',
#  'Brady!',
#  "NO I DON'T YOU BITCH!",
#  "What's not right?",
#  "In the hands of a mature civilization these would not be considered weapons of aggression. But in the hands of your people--  We've observed your aggressive tendencies and we don't trust you with such power.",
#  'What kind of a life is that?',
#  "You better not be fuckin' teasin' me.",
#  "That's good coke.",
#  'Do what--',
#  "I don't know.",
#  "Then that's the place for us!",
#  'Tempt not a desperate man!',
#  'Words.',
#  'They know what--this fella looks like?',
#  'I was honest with you. I told you who I was.',
#  'You bet! "The Harold Ryan Fan Club." Pink eh?  With a yellow streak up the back.  We got very good tailor shops up here.  They\'ll make you any kind of uniform any kind of sweatsuit you want.  Judas Iscariot--he\'s got this black jacket with a skull and crossbones over the heart.  He walks around all hunched over and he never looks anybody in the eye and written on the back of his jacket are the words "Go take a flying--',
#  "Look at this!  The dog!  She's dead!",
#  'OK I bite. What does it look like?',
#  "- that's what I mean!",
#  'Yes and very beautiful.',
#  'I prefer to wait until we can share the benefits with all the people of the Federation...',
#  'Yes sir.',
#  "You didn't answer my question. In fact for the last 18 hours no one has answered any of my questions.",
#  "It gave me a little chance and I took it. They won't get me back. I'm going to live and you're going to help me. Yes?",
#  "V'asitem lechem pessel to-monat. And make no graven image of the Lord or the form of any figure or of man or woman or beast or fowl or fish or anything that looks like anything. Because He's not like anything. Not only can't you see Him or hear Him you can't even think about Him. I mean what's the difference between that and Him not existing?",
#  'Is this where no one stays?',
#  "That's Sherry VanHafton.",
#  'Will you two cut it out?',
#  'We are being fucked with here someone or something.',
#  "I'll bet she has a call caddy right next to her phone.",
#  'Yes.',
#  "'Cause your lips is getting black.",
#  "It's about this.",
#  '"Big Brother" "Little Brother"?',
#  "But I think I know where she'll be....",
#  'This is all my fault.',
#  'Shall I tell you something -- I believed what was called love came after the union -- and I was surprised when my husband making me a woman made me know it only by pain unaccompanied by any pleasure. I saw that my imaginings had stood me in better stead.  And so we became only friends seldom sleeping together and arousing no curiosity in each other yet on good terms for a while as whenever he wanted me I was at his service but since the offering was not seasoned with love he found it tasteless and seldom demanded it.',
#  'You mean Jacobi put it in between when this film was made and when he was murdered?',
#  'Will you let me talk to you please?',
#  "There's no loyalty at the expense of my own ass.",
#  'You got me peanut.',
#  'Oh. Well wasn\'t it Shakespeare who said: "When strangers do meet they should erelong see one another again"?',
#  'Want to come again and stay',
#  'Can you shut it down?',
#  "It's Elijah.",
#  "What of it? Then it'll be out of it's misery.",
#  'Uh huh.',
#  'And what is the percentage of the Tattaglia family?',
#  'Yes sir.',
#  'Not by the thousands.',
#  'Not that one.  Or that one.',
#  'Because this must be stopped.',
#  'I thought for sure they would catch me.',
#  "Well it's Billy.",
#  "I'm staying here with him 'til the plane gets safely away.",
#  'I never tried to get you to like me.  I tried to get you to love me.',
#  'Had the FBI here once before. Back in the fifties when Hap was running the place.',
#  'I asked you a question Lothar!',
#  'Ho -- ho --ho',
#  'Uh...sure...when?',
#  "No no... not exactly... she just doesn't understand how I would know somebody like you...",
#  "I'm doing what any man would do if he'd been offended.  I'm stompin' your ass.",
#  'Thought you were going to buy a car.',
#  "Excuse me I'm having a goddamn party is that allright with you?",
#  '...Yes.',
#  'You know what happened.',
#  "Are real?  How do you know you're not hearing things? How do you know I'm not someone in your head? Somewhere you know.",
#  'Mmm...',
#  'Kay had a miscarriage; she lost the baby.',
#  "No. You don't.",
#  'So to speak.',
#  '"Our" car Walter?',
#  "I don't want to take up your time now but I was hoping you could give me some information on somebody. It's a security level three matter and Information Retrieval records says to refer to you.",
#  'What can we do to assist you?',
#  "You wouldn't be here otherwise.",
#  "Maybe you'll think of something...",
#  "Don't you work here?",
#  "You don't have a boyfriend or anything do you?",
#  "I believe you Austin. Let's go.",
#  "He's coming 'round Jim...",
#  'Thanks but Miss Dawson and I are going out to see the sights.',
#  'Marla...',
#  "Yeah well I'm going to work as a cowboy now... Or thinking about it. It's a routine like anything. What do you think?",
#  "It's the only vein I know.  I tell the facts the way I see them.  And any man that knows that facts -",
#  "I'm here.",
#  'Hello?',
#  "We'll see. If it doesn't what the hell at least I gave it a shot.",
#  'Troughed off. Protected. Like you know like he got a moat around it.',
#  "I've known Susan for more than fifteen years.  James we're old allies.",
#  "You've got quite a temper.  It's better this way.",
#  'What list?',
#  'Be a man man.',
#  "Get it through your head little girl; I'm not going for you.  If this Toby likes you then if I were you I'd marry him.  You're not going to get much better in this town.",
#  "She's around. Always is.",
#  'You seem pretty sure of the date. Did I ask you to sit?',
#  'If you\x92re into that kind of conspicuous consumption...',
#  "Mr. Mayor it's a pretty simple choice. You can believe Mr. Pecker here ...",
#  "You'll love it.",
#  'He was like a total babe',
#  "Anastasia! It was just a bat! It's gone dear...",
#  "Yes there was a man with you... She brought you here... She didn't know what else to do.",
#  'AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA.',
#  "Don't look back! Act naturally!",
#  "I'm not.",
#  'Is it fifteen minutes yet?',
#  "I need this Roy. I can't run without money and if I can't run I'm dead.",
#  "I don't actually think Jeffrey's gonna notice.",
#  "If she's not now Terry will make sure she is by the end of the evening.",
#  "From Boston. Evan Twombley's son-in- law -- he was driving. I know where they're headed. Up the lake Agaway. The old man's out deer hunting with Jack Hewitt so they probably got some big weekend party planned.",
#  "If you think we're going to have some kind of 'life affirming' romance here just because we cheated death let me be clear:  We're going to have it where I want and when I want.",
#  "Tomorrow I'll steal you another.",
#  'No no no you said "The Number Four With a Smile and there\'s no The" at the front of the title of the album.',
#  "I know it must be hard. But you have relatives in London --you've got a whole world of living ahead of you --",
#  'Enough talk write.',
#  'Have you seen my dog anywhere?',
#  "We ain't goin' to Nebraska on no turtle hunt. A hundred yards?",
#  "What's gonna happen?",
#  "It doesn't matter. There is no exit visa for him.",
#  'You may ask Lieutenant.',
#  "Hey Janet it's Chad.",
#  'What do we want?',
#  'You ass.',
#  'With her? How?',
#  "Oh.  Mom.  It's Brad.",
#  'I know...',
#  'Tell me.',
#  "Yeah thanks for going back to hell for us. You're a real pal.",
#  "That's why when I was little I never went to live with my mother.",
#  'Say that again.',
#  "Do as you wish with my body you'll never possess my soul!",
#  "Do you realize how hard it's going to be to tell my parents? I still haven't told them I didn't get the pilot.",
#  'Wanna play?',
#  "Kissing?  Is that what you think happens?  Kissing isn't what keeps me up to my elbows in placenta all day.",
#  "Yeah. He'll have a tough time thinking up a wise-crack for this one . . .",
#  "It's nothing to be ashamed of --",
#  'Yeah?  What did we ever do?',
#  'Okay.',
#  'Suzie!  Did this man rape you?',
#  "About Charlie's leopard?",
#  "I never go upstairs. You're a nice old lady.",
#  'Oh I see I thought you meant --',
#  'Try the closet.',
#  'Way I look at it I actually perform a humanitarian service.  I save lives.',
#  "Yeah so I've been thinking.  I love her y'know?  I kind of want to have her.  I've been away for so long.  Make up for the missed time you know?",
#  'Get out of my hotel.',
#  '&lt;&lt;Are you sure?&gt;&gt;',
#  "- Because it's good!",
#  'Souse! Souse! He manages to write his name on the back of his paycheck every week!',
#  'Mrs. Lampert any morning now you could wake up dead.',
#  'Hi.',
#  "I'm going to call the police. I'm going to watch you play the great Baron with the police. Aristocrat! Aristocrat! ",
#  "There are people down there having fun. I want to be one of them. I want you to be one of them. On Monday you can be a bank teller if you want but tonight you're a bootlegger with a truck full of Puerto Rican rum and a fistful of cash.",
#  'That\x92s my car!  You stole my car!',
#  "So you're telling me the truth <u>this</u> time?  Is that it!",
#  "I cannot accept a connection between David Kessler and last night's murders. We will find him however. I can assure you of that.",
#  "You wouldn't be putting me out.",
#  'Sure.  I could take a fishing gaff and split your head open. Right above your left ear.',
#  'What will you say about us?',
#  "Yeah a man's drink...",
#  "Yeah. And they say smokin' is bad for your health.",
#  'That was Gary Cooper shithead...',
#  'Who use to own it?',
#  'He has a lot of hurt inside him.',
#  "It's not just for myself I'm asking. Her sister is here. The kid's half crazy with anxiety.",
#  'I am a patriot. I love my country. Can you understand that?',
#  "I love somebody.  All the time I've been looking for someone to love me and now--I love somebody.  And it's so easy.  Why is it easy now?",
#  'Yes I know who he is.',
#  "How can we not say the word if you don't tell us what it is?",
#  'Do say hello to your mother.',
#  'Hush!',
#  "How're you holding up?",
#  'We have to call the ambulance.',
#  'Unbelievable.',
#  'Dewey?',
#  'What did he say?',
#  "Told you so.  Alright.  We tried.  Let's go home.",
#  "When you get back I'll be gone --",
#  "That's it? I mean you don't want to order room service or anything? We could play games and watch movies and stuff.",
#  'You like to hang out with murderers or what?  Did you know Roxy --',
#  'Oh lawyers got fat and the judge got famous but someone forgot to sign the search warrant in the right place and Fred Krueger was free just like that.',
#  'Oh.',
#  'I brought these walnuts to trade.',
#  'Fifty-seven fifty-eight --',
#  'What was I trying to say? Oh yes I think we think or at least I suppose we think -- am I right?',
#  'DAMN IT BE SURE!!',
#  'How is it going to be different from this?  Go see some boring footprint under glass?',
#  "They're all saying the word ...",
#  "It's like the Garden of Eden...",
#  'A traveler eh?',
#  'I think that you know.',
#  'And my hair...what color hair did Barbara have?',
#  'We gotta face some facts here.',
#  "We made our collection at Roderick's place and that was the last anybody seen hide nor hair of him.  He went missing the next day along with ten thousand dollars in county funds from the safe at the jail.",
#  'All right.  What do we do now?',
#  '-- the hardest and the greatest.',
#  'I think that is its hand.',
#  'You like me better like this.',
#  "Case daddy don't like me. What if he don't like that I don't got his color hair.",
#  'Yes sir.',
#  "You're Woogie?",
#  'What is your problem?',
#  "I don't know. I've never thought about it... what was the most exciting place you've ever been to? Unless you're tired of talking about it.",
#  "You're not going to bet it all....",
#  'What are you doing?',
#  'Hey Juno... A couple of us are going to the cineplex after school to donut that movie with the guy with eighteen kids.',
#  "And you're saying a fella could take and sell these leads to Jerry Graff.",
#  "I'm getting pneumonia. I have a fever. Feel my forehead...",
#  'Spanish kinda guys!',
#  "I'd go with number three.",
#  'Oh.  Well for Blackie then.',
#  "Would you?  It's all talk talk talk.",
#  "You're back!",
#  'There is that.',
#  "I'm a witness to a murder.  That seems to put me pretty high on your friend's chop list.",
#  'No.  I came to talk about Dr. John Whittlesley.',
#  "Who's he?",
#  "One Zulu is only one man.. ..and I'm afeared of no one man... but the Zulu they come in the thousands.... like a black wave of death.... in the thousands.... and them assegais.... stabbing!",
#  'Not because you were attracted to him?',
#  'Yeah.  You know Baxter I envy you. Bachelor -- all the dames you want -- no headaches no complications --',
#  'But when you fall asleep I do things without you...',
#  'I begged him to stay in the cover of the trees but he insisted the only way to break Cornwallis was muzzle- to-muzzle.  He spent too many years in the British army.',
#  "Then you'll be wet.",
#  'I understand.',
#  "I don't see the connection.",
#  'So this is the last time I see you then unless I do bad?',
#  "They can't pull this on me. It isn't fair--I don't believe this--",
#  'No sir.',
#  "Don't fuckin' patronize me.",
#  "I'm sorry pal but I had a meeting and--",
#  'What kinds of questions?',
#  'Some Hollywood movie star her plane got in late.',
#  'You want me to keep that under the table for you?',
#  "When I was at the rest stop there was a young boy maybe ten and his mother. Darryl Hawkins Zero abducted the boy in the men's room. I tried to stop him. He cold-cocked me --",
#  "We don't serve formula. Snookums.",
#  "You don't know?",
#  "There's an understatement.  There are dead people on better form.",
#  'I hope you live to see what I believe...',
#  'Hey Murph.',
#  'You promised!',
#  "He said that father's in town. He's been seeing Julia right along.",
#  'Okay I suppose I should go home.',
#  'Not really...',
#  'Picked it up in Shanghai -- which has also seen better days.',
#  "Saunders I've lit cigarettes -",
#  'Did she say that?',
#  'Food for crows.',
#  'The Road Research Laboratory? Where they simulate car crashes?',
#  'Let me get a pen out of my car.  Do you have something to write on?',
#  "Yeah 20 minutes.  Trust me.  I've been pepper sprayed nine times.  20 minutes.",
#  "I've seen it. It's all pain.",
#  'I do not accept.',
#  "Even so I could never think of going on -- I've got to find some other profession.",
#  'I bullshitted him.',
#  "He took him over. His body. His -- his brain everything what he knew. He's only been dumb stuff before amoeba--things and rhino--things. He liked being human. Didn't want to change.",
#  'Hard to find it sitting by the pool drinking beer and bullshitting.',
#  "No I don't.  I'm not Jack ...",
#  "That's one - way of looking at it.  You might also say this guy is brainless he has no brain'.",
#  'Just relax.',
#  "The shields in that section won't protect them against the thermolytic reaction...",
#  'Work that up into a comic strip and syndicate it.',
#  "I can't help it. It just keeps ringing.",
#  "Maybe they're Mary's.",
#  'The hell you do. At this hour?',
#  'The bottoms of your feet are covered with salt.',
#  'Look ah we never talked much you and me...',
#  "It's inside the complex.",
#  "Check this out. It's a memo about how they're gonna deal with those oil spills that happened on the fourteenth.",
#  "I'm nothing but a body with a voice. No mind.",
#  'Sorry!',
#  'Yes -- that --',
#  'Same thing Giuliani said.',
#  'off the peg?',
#  "I'm feeling okay--",
#  "I'm not expecting anyone.",
#  "A marker's like a check Harry.",
#  'Vance!  Vance Parker.',
#  "No false modesty lad.  You're a proper champion.  Achilles' armor sits on you like it was forged to fit.",
#  'Whadaya say?',
#  "That's true. But what if they change the locks?",
#  "Lousy day?  The man's getting out of prison and he's having a lousy day.  What you missing out on the Cell Block Water Ballet pageant?  Believe me it's overrated.",
#  'Sorry?',
#  'My sixth-grade science project was entitled \x93Love Hurts: The Heartbreak of Human Papillomavirus.\x94 Trust me I\x92m careful.',
#  'Dirty night.',
#  'Klupner.  Mrs. Klupner.',
#  "I can't believe the Captain went along with a memory download.",
#  'Like what?',
#  'Jesus its huge.',
#  'Starck give me a read.',
#  'Jason..',
#  'Would you get that dear?',
#  "No. I mean I don't believe it. Lilly is not a suicide. I know my mother nothing would make her check out.",
#  'Wait a second...',
#  'Nothing.',
#  "Hey Sonny!  I'm watchin' it on TV!",
#  "I quit workin' for 'im but just before I did I ended up one night at a house... I don't know what it is they all think I saw that night but I was just sittin' out in the car till the whole place went up in flames.",
#  'Do you freely admit to the charges made against you ?',
#  "Don't let that worry you Annette!",
#  'That happens.',
#  'Jezebel from the post office. You remember you met her that time at the Christmas party. I was living with her. God it was a nightmare. There were all these demons and I was on fire. Only I was burning from ice.',
#  '... How long have I been out?',
#  'Our abstinence makes our love immortal.  If I loved you a quarter of an hour ago now I should love you even more.  But I should love you less if you exhausted my joy by satisfying all my desires.',
#  'I know it starts with a birth certificate...',
#  'American.  Come to get you out.',
#  'You take cream or sugar?',
#  "Whatsamatter kid what's botherin' you...?",
#  'God I hate that bitch.',
#  'Kramer the WORP control handle just came off in my hand.',
#  "Let's take her into an escape orbit.",
#  'My father did not think of my mother -- his family -- as a burden.',
#  'Who are you?',
#  'Thanks. Sure is a hot day for driving. Late afternoon is better. You guys have plenty of time. Make Pittsburgh in two maybe three hours.',
#  'What?',
#  'I now understand the expression "you get what you pay for!" A bunch of chumps!',
#  "I brought it with me from 1982. It's from my science book.",
#  'The next thing... his hand was in my shorts... you know from behind.  His fingers... his fingers...',
#  "It's some kind of organ -- it's inserted some kind of tube or something down his throat.",
#  "Cuervo's got a place near Venice where the big birds fly. Nice digs too. I've been there y'know.",
#  'Admiral this is Spock.',
#  'Your honeymoon Meyer?',
#  'Hello?  Hello!?  Operator I got disconnected.  Hello . . .',
#  'The other night you said the modern world is a Jewish disease. Could you elaborate on that?',
#  "We have a new directive. I'm taking over.",
#  'It hurts that you would say that to me.',
#  "I'm leaving and don't even call me when the shoe falls 'cause all he did for me was to try and run my life. I'm tired of people saying Babe Brother this Babe Brother that. What's my name?",
#  "Isn't that what they always say?",
#  "Fill them with cement brick them up put land mines in them bombs I don't know just make sure that goddamned thing doesn't leave the island!",
#  'Yes it is.',
#  "What if he was?  Do you think he wanted to bring that up again just when you're trying to make a new start?",
#  'Me.',
#  'Thanks.  But this morning I was thinking about it and I realized that I looked forward to it all year. And then I thought "Gee. That seems awfully silly. That seems like an awfully long time to be waiting for just one moment don\'t you think?"',
#  'Are you sure? Because I can take it back.',
#  "I mean it's okay if you want to sit down here. I didn't mean to --",
#  "This is bullshit George.  We're never going to find anything down there.",
#  "What in the hell do you think I'm doing? Taking out her tonsils?",
#  'You are cattivo Court Composer.  I want to meet this young man. Chamberlain arrange a pleasant welcome for him.',
#  "That'd be seventy in New York. You stole it!",
#  "Lizt was my parents' favorite they were Hungarian.",
#  "They don't know. It was carefully planned. Earlier in the day the victims received anonymous passes to the movie.",
#  "So what?  I've got three satchel charges six gammon grenades a dozen- and-a-half pineapples and all my regular gear.  You don't hear me complaining.",
#  'Hunting -- we had to hunt him --',
#  'You seek facts when it would be better to seek truth.',
#  'You having fun?',
#  "Oh I don't know.",
#  'Just reporters.',
#  "It's a specialty down there.  It's a fishing boat with in front a long pole near the surface. Then near the cabin a very tall mast with a little cabin for the lookout.",
#  'What are you hoping to find inside?',
#  'True.',
#  "You can't send him back to Oklahoma. It'd be inhumane.",
#  "Excuse me I don't mean to harass you but I was very impressed by the capable and stylish manner in which you dealt with that situation. I thought to myself: she's special.",
#  'You can stop right there.',
#  'Yes.',
#  "Do I need to remind you what happened to his wife? To his daughter?  I will stake my reputation that Barnes didn't kill those guards.",
#  'Okay.   You can be Elvis.',
#  'Pablo said no?',
#  'The other ones?',
#  "What'd they take?",
#  "Oh Miles. You're drunk.",
#  'Uh huh pleasure.',
#  'I thought you ought to know Arlyn Page is dead.',
#  "He can't drink this milk. It'll make him sick. He's on a formula.  I was a fool! I shouldn't have kept him with me.",
#  'TIME TO GO!',
#  "Ought to be. That's fact'ry liquor. Cost me a buck.",
#  "What? No frigging way man. I'm not touching that thing.",
#  "How you feelin'? Ok? You feelin' good?",
#  'A date... Coffee... A drink...A walk in the park.',
#  'That which has been hidden in darkness is now in the light.  This bucket of blood.',
#  'Yeah.',
#  'Is that how you think of yourself?',
#  "I wouldn't take no cheap shots. I'd be a good sparrin' partner.",
#  'Does it float?',
#  'Me and Hap.  A year and a half ago.  I knew the second I met Dobbs that he was guilty.  Smug cold.  Dead eyes.  We had circumstantial evidence but nothing to tie him to it.  Nothing concrete.  Went over every inch of that apartment.',
#  "It's pretty embarrassing. I really don't know what to tell Mr. Robinson. It's awkward and strained for me every time he suggests that you call up Elaine.",
#  'What night is that?',
#  "Every place has hookers but if this hotel has hookers they don't look like they're...",
#  "Don't.",
#  "We're not animals but don't force us to be.  Walk over.",
#  'Jim Sullivan. Sometimes they call me Jism Jim.',
#  'You go first.',
#  'Your wish is my command.',
#  'Hey Rick!',
#  '...Pete!  Come on.',
#  'We stopped seeing each other.',
#  'You have to make a decision: is this guy partner material?',
#  "There's something very familiar about this painting.",
#  "Well providing we're treated like Czechs and we squat something that's not privately owned we should be in the clear; at least DOUG  until they get an eviction order and bring in the bailiffs.",
#  'What!?',
#  'I thought you were an expert.',
#  'Okay but it has to be a small one.',
#  'No.',
#  "The greatest yarn ever written by anybody. My hat's off to you Hildy!",
#  'C-4?',
#  'Affirmative Captain. Our readings are well below danger level.',
#  'No!',
#  'That you meet with me twice a week--',
#  'Say "goodnight" to Sandy.',
#  "Trust you and Harry Lee.  Remember that damned overland you two thought up in '62 to hit Fort Louis?",
#  'Not me.',
#  'But why would they --?',
#  'Fair enough.',
#  'John.  John you all right?',
#  "Then it's still no.",
#  'No.',
#  "--maybe I'm tense--",
#  'All right. What happened to our bracelet?',
#  "Kalen right now you need to go up to bed.  You're exhausting Alexander.",
#  'No not exactly a man of the people.  "Also known as Vigo the Cruel Vigo the Torturer Vigo the Despised and Vigo the Unholy."',
#  "Of course not... he's sort of a boyfriend.",
#  "... I just pray we're not too late.",
#  'Is that bubble what I think it is?',
#  "That's funny we've got five thousand horses but no men.",
#  '-- you could put it together --',
#  "It's a Noaa buoy.",
#  "Professor Brown grinned. I guess I'll see you in... about 30 years.",
#  'Two days.',
#  'Forbear this outrage good Mercutio.',
#  'Quid pro quo Doctor.',
#  'Enjoy.',
#  'Deepcore this is Cab One.  We need assistance over.  Deepcore this--',
#  "You little bitch! How could you? Was there ever a baby Lynette? That's all I want to know! Did you make up that baby Lynette? Did you??",
#  'Victory is mine.  I thank thee O Lord that in thy ...',
#  'He was my Grandfather too.',
#  "That ain't me.",
#  "See? I see. It's you who don't see. Doesn't see. I cannot believe it! How you people fail to grasp the long-range significance of this! Y'know?",
#  ...]

# %%
nav_int_file = open('nav_int.txt','r')
size_int_file = open('size_intent.txt','r')
bbt_store_list_file = open('bbt_store_list.txt','r')

nav_int = []
size_int = []
bbt_store_list = []
for l in nav_int_file.readlines():
    nav_int.append(l.strip())

for l in size_int_file.readlines():
    size_int.append(l.strip())
    
for l in bbt_store_list_file.readlines():
    bbt_store_list.append(l.strip())

bbt_store_list = [x.split('.') for x in bbt_store_list][:-2]
bbt_store_dict = {}
for el in bbt_store_list:
    bbt_store_dict[el[0]] = el
    
all_store_names = []
for el in bbt_store_list:
    all_store_names += el

# %% [markdown]
# Now we replace insert with the names and create question marks

# %%
appended_nav = []
appended_size = []

for store_name in all_store_names:
    
    for nav_eg in nav_int:
        new_data = nav_eg.replace('insert', store_name)
        appended_nav.append(new_data)
        appended_nav.append(new_data+"?")
    
    for size_eg in size_int:
        new_d = size_eg.replace('insert', store_name)
        appended_size.append(new_d)
        appended_size.append(new_d+"?")

print(len(appended_nav))
print(len(appended_size))
# Out:
# 2880
# 1920

# %% [markdown]
# Combine All Together

# %%
nav_frame = pd.DataFrame({"Data":appended_nav,"Label":[1]*len(appended_nav)})
size_frame = pd.DataFrame({"Data":appended_size,"Label":[2]*len(appended_size)})
diag_frame = pd.DataFrame({"Data":lol1,"Label":[0]*len(lol1)})

data_set = pd.concat([nav_frame, size_frame,diag_frame]).reset_index()
data_set = data_set[data_set['Data'] != ""]
data_set['question'] = data_set['Data'].apply(lambda x: x[-1] == "?")

# %%
data_set = data_set.sample(frac=1)
train_set = data_set[0:5000]
test_set = data_set[5000:]

# %%
train_docs = train_set['Data'].values.tolist()
train_labels = train_set['Label']

test_docs = test_set['Data'].values.tolist()
test_labels = test_set['Label']

# settings that you use for count vectorizer will go here
tfidf_vectorizer=TfidfVectorizer(use_idf=True)
train_tfidf=tfidf_vectorizer.fit_transform(train_docs)
test_tfidf=tfidf_vectorizer.transform(test_docs)

# %% [markdown]
# # Intent Recognizer

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
intent_clf = RandomForestClassifier()

intent_clf.fit(train_tfidf, train_labels)
test_preds = intent_clf.predict(test_tfidf)

# Get accuracy
acc = np.mean(test_preds == test_labels.values)
print("Acc: " + str(acc))
print("Confusion: ")
print(confusion_matrix(test_labels, test_preds))
# Out:
# Acc: 0.996104618809
# Confusion:
# [[511   4   3]
#  [  0 784   0]
#  [  0   0 495]]

# %%
# Save the classifier and vectorizer
pickle.dump(intent_clf, open('intent_rf.pkl', 'wb'))
pickle.dump(tfidf_vectorizer, open('tfidf_trans.pkl','wb'))

# %%
bbt_store_dict
# Out:
# {'alley': ['alley', 'the alley'],
#  'bober tea': ['bober tea', 'bober', 'bobertea'],
#  'chicha sanchen': ['chicha sanchen',
#   'chicha',
#   'sanchen',
#   'chi cha',
#   'san chen'],
#  'each a cup': ['each a cup', 'eachacup', 'each acup', 'eacha cup'],
#  'gongcha': ['gongcha', 'gong cha'],
#  'heytea': ['heytea', 'hey tea'],
#  'hitea': ['hitea'],
#  'holin': ['holin'],
#  'itea': ['itea'],
#  'jenjudan': ['jenjudan', 'jen ju dan'],
#  'liho': ['liho', 'li ho'],
#  'milksha': ['milksha'],
#  'playmade': ['playmade', 'play made'],
#  'sharetea': ['sharetea', 'share tea'],
#  'tiger sugar': ['tiger sugar', 'tiger sugar'],
#  'tptea': ['tptea', 'tp tea'],
#  'woobbee': ['woobbee'],
#  'xinfutang': ['xinfutang',
#   'xingfutang',
#   'xin fu tang',
#   'xing fu tang',
#   'xft']}

# %%
import re

def store_recognizer(input_string, store_list, all_store_dict):
    '''
    takes as input an input string and finds the bubble tea store name
    always returns the base form of the name that is in the database
    '''
    
    for store_name in store_list:
        if re.search(store_name, input_string):
            # Find correct form
            for key_string, val_list in all_store_dict.items():
                if store_name in val_list:
                    return key_string
    return None

# %%
def get_location(input_string):
    output = re.findall("[0-9][0-9][0-9][0-9][0-9][0-9]",input_string)
    return output[0]

# %%
# !ls
# Out:
# Intent_trainer.ipynb  bbt_store_list.txt   dialogues.tsv    size_intent.txt
# README.md	      common		   main_bot.py	    utils.py
# __pycache__	      data		   movie_lines.tsv  week5-project.ipynb
# bbt_locations.csv     dialogue_manager.py  nav_int.txt

# %%
data_loc = pd.read_csv('bbt_locations.csv')

# %%
data_loc
# Out:
#         Brand                                      Location_Name  \
# 0     gongcha                              1 Raffles Place (1RP)
# 1     gongcha                                 313 Somerset (313)
# 2     gongcha                                   Ang Mo Kio (AMK)
# 3     gongcha                                Bugis Junction (BJ)
# 4     gongcha                               Causeway Point (CWP)
# 5     gongcha                               Century Square (CSQ)
# 6     gongcha                              Changi Hospital (CGH)
# 7     gongcha                                  Compass One (COM)
# 8     gongcha                                  Eunos MRT (EUNOS)
# 9     gongcha                                       FUNAN Centre
# 10    gongcha                                 Hougang Mall (HGM)
# 11    gongcha                     Mapletree Business City (MTBC)
# 12    gongcha                                Marina Square (MSQ)
# 13    gongcha                                    Northpoint (NP)
# 14    gongcha                NUS Science Canteen Frontier (NUSF)
# 15    gongcha                                    NUS UTown (NUS)
# 16    gongcha                                Pasir Ris MRT (PRM)
# 17    gongcha                                   Plaza Sing (PZS)
# 18    gongcha                                    Simei MRT (SMM)
# 19    gongcha  Singapore University of Technology & Design (S...
# 20    gongcha                                      Singpost (SP)
# 21    gongcha                                 SMU café 2.0 (SMU)
# 22    gongcha                                 Takashimaya (TAKA)
# 23    gongcha                                Tampines MRT (TMRT)
# 24    gongcha                      Tan Tock Seng Hospital (TTSH)
# 25    gongcha                                    Toa Payoh (TPY)
# 26    gongcha                                      Westgate (WG)
# 27    gongcha                                Woodlands MRT (WLM)
# 28   sharetea                                Woodlands MRT (WLM)
# 29   sharetea                                     Parkway Parade
# ..        ...                                                ...
# 284  eachacup                  Each-A-Cup (Blk 306 Ubi Avenue 1)
# 285  eachacup              Each-A-Cup (87 Marine Parade Central)
# 286  eachacup                     Each-A-Cup (Bukit Timah Plaza)
# 287  eachacup                   Each-A-Cup (Tanjong Pagar Plaza)
# 288  eachacup             Each-A-Cup (Blk 525 Ang Mo Kio Ave 10)
# 289  eachacup                             Each-a-Cup (Marsiling)
# 290  eachacup                         Each-a-Cup (Wisteria Mall)
# 291  eachacup            Each-A-Cup (Blk 417 Yishun Mall Ave 11)
# 292  eachacup       Each-A-Cup (The POIZ Centre) - Opening Soon!
# 293  eachacup         Each-A-Cup (Yishun Ring Road @ Chong Pang)
# 294  eachacup                        Each-a-Cup (Rivervale Mall)
# 295  eachacup                              Each-a-Cup (E!Avenue)
# 296  eachacup                 Each-a-Cup (443 Pasir Ris Drive 6)
# 297  eachacup                  Each-a-Cup (Leisure Park Kallang)
# 298  eachacup                           Each-a-Cup (Bedok Point)
# 299  eachacup                    Each-A-Cup (477 Tampines St 43)
# 300  eachacup             Each-A-Cup (Blk 208 Bedok Town Centre)
# 301  eachacup                      Each-A-Cup (Blk 12 Haig Road)
# 302  eachacup                       Each-a-Cup (Senja Cashew CC)
# 303  eachacup                      Each-a-Cup (ITE College West)
# 304  eachacup                 Each-a-Cup (502 Jurong West Ave 1)
# 305  eachacup      Each-a-Cup (Nanyang Technological University)
# 306  eachacup                         Each-a-Cup (One North MRT)
# 307  eachacup   Each-a-Cup (Bt Panjang Integrated Transport Hub)
# 308  eachacup                             Each-a-Cup (Dover MRT)
# 309  eachacup                             Each-a-Cup (West Mall)
# 310  eachacup                       Each-a-Cup (Ng Teng Fong GH)
# 311  eachacup        Each-a-Cup (Library @ Ngee Ann Polytechnic)
# 312  eachacup                        Each-a-Cup (Causeway Point)
# 313  eachacup                     Each-a-Cup (SIT @ NP Building)
#
#                                       Location_Address
# 0    1 Raffles Place, #B1-39, Shopping Podium Tower...
# 1           313 Orchard Road, #01-37, Singapore 238895
# 2     703 Ang Mo Kio Ave 3, #01-2531, Singapore 560703
# 3    Bugis Junction, #03-08, The Victoria Street , ...
# 4    Causeway Point 1 Woodlands Square, #02-K10, Si...
# 5    2 Tampines Central 5, #01-39, Century Square, ...
# 6           6 Simei Street 3, #01-03, Singapore 529898
# 7    Compass One 1, #02-40/41, Sengkang Square, Sin...
# 8    30 Eunos Crescent, #01-10, Eunos MRT Station, ...
# 9              109 North Bridge Road, Singapore 179097
# 10   10 Hougang Mall, 90 Hougang Ave 10, #B1-14/15,...
# 11             10 Pasir Panjang Road, Singapore 117438
# 12      6 Raffles Boulevard, #03-212, Singapore 039594
# 13   930 Yishun Avenue 2, #01-06, North Wing Of Nor...
# 14                12 Science Drive 2, Singapore 117549
# 15   Fine Food @ NUS UTown,1 Create Way, #01-04 NUS...
# 16   10 Pasir Ris Central, #01-14, Pasir Ris MRT St...
# 17   68 Orchard Road, #B1-K7, Plaza Singapura, Sing...
# 18   30 Simei Street 3, #01-04, Simei MRT Station ,...
# 19           8 Somapah Road, #01-302, Singapore 487372
# 20   10 Eunos Road 8, #01-141A/141B, Singapore Post...
# 21   50 Stamford Road, #01-01, Lee Kong Chian Of Bu...
# 22   391A Orchard Road, #B2 08-7, Takashimaya Depar...
# 23            20 Tampines Central 1, Singapore, 529538
# 24   16 Jalan Tan Tock Seng, #B1-03, Tan Tock Seng ...
# 25   Blk 190 Lorong 6, Toa Payoh #01-546, Singapore...
# 26   3 Gateway Drive, #02-27, Westgate, Singapore 6...
# 27   30 Woodlands Avenue 2, #01-40, Woodlands MRT S...
# 28   Woodlands MRT #0101-26 Woodland AVE 2, Singapo...
# 29     80 Marine Parade Road, #B1-21, Singapore 449269
# ..                                                 ...
# 284                        Blk 306 Ubi Avenue 1#01-195
# 285  87 Marine Parade Central #01-503B Singapore 44...
# 286  1 Jalan Anak Bukit #K1-CS1 Bukit Timah Plaza S...
# 287  Blk 1 Tanjong Pagar Plaza #01-15 Singapore 082001
# 288  Blk 525 Ang Mo Kio Ave 10 #01-2395 Singapore 5...
# 289  Blk 302 Woodlands St 31 #01-287\n \n Singapore...
# 290  Wisteria Mall - 598 Yishun Ring Road #01-22 Si...
# 291  Blk 417 Yishun Mall St 11 #01-347 Singapore 76...
# 292  51 Upper Serangoon Road #01-10 The POIZ Centre...
# 293  Blk 106 Yishun Ring Road #01-151 Singapore 760...
# 294  11 Rivervale Crescent #01-K7\n \n Singapore 54...
# 295       1, Pasir Ris Close, #02-K2, Singapore 519599
# 296  443 Pasir Ris Drive 6 #01-14\n \n Singapore 51...
# 297            5 Stadium Walk, #01-30 Singapore 397693
# 298  #02-24, Bedok Point, 799 New Upper Changi Rd, ...
# 299  Blk 477 Tampines Street 43 #01-174 Singapore 5...
# 300  Blk 208 Bedok Town Centre New Upper Changi Roa...
# 301          Blk 12 Haig Road #01-331 Singapore 430012
# 302  101 Bukit Panjang Road #01-03\n \n Singapore 6...
# 303  1 Choa Chu Kang Grove #05-01\n \n Singapore 68...
# 304  Blk 502 Jurong West Ave 1 # 01-825\n \n Singap...
# 305     50 Nanyang Ave NS3-01-21\n \n Singapore 639798
# 306   9 Ayer Rajah Avenue #B2-01\n \n Singapore 138647
# 307  Bt Panjang Integrated Transport Hub â€“ 15 Pet...
# 308  200 Commonwealth Ave West, #02-02 Singapore 13...
# 309  1 Bukit Batok Central Link, #01-07 Singapore 6...
# 310  1, Jurong East St 21, #02-27 Tower A Singapore...
# 311  535, Clementi Road, Blk 1, Library, Singapore ...
# 312              1 Woodlands Square #B1-K19, Singapore
# 313  Ngee Ann Polytechnic, 537 Clementi Road, Singa...
#
# [314 rows x 3 columns]

# %%
current_location = '570163'
bubble_tea_store = 'gongcha'

sub_frame = data_loc[data_loc['Brand']==bubble_tea_store]
sub_frame['Postal'] = sub_frame['Location_Address'].apply(lambda x: get_location(x))
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
sub_frame.head()
# Out:
#      Brand          Location_Name  \
# 0  gongcha  1 Raffles Place (1RP)
# 1  gongcha     313 Somerset (313)
# 2  gongcha       Ang Mo Kio (AMK)
# 3  gongcha    Bugis Junction (BJ)
# 4  gongcha   Causeway Point (CWP)
#
#                                     Location_Address  Postal
# 0  1 Raffles Place, #B1-39, Shopping Podium Tower...  048616
# 1         313 Orchard Road, #01-37, Singapore 238895  238895
# 2   703 Ang Mo Kio Ave 3, #01-2531, Singapore 560703  560703
# 3  Bugis Junction, #03-08, The Victoria Street , ...  188021
# 4  Causeway Point 1 Woodlands Square, #02-K10, Si...  738099

# %%
def get_distance(current_location, bubble_tea_store):
    return 5
# Out:
# {'alley': ['alley', 'the alley'],
#  'bober tea': ['bober tea', 'bober', 'bobertea'],
#  'chicha sanchen': ['chicha sanchen',
#   'chicha',
#   'sanchen',
#   'chi cha',
#   'san chen'],
#  'each a cup': ['each a cup', 'eachacup', 'each acup', 'eacha cup'],
#  'gongcha': ['gongcha', 'gong cha'],
#  'heytea': ['heytea', 'hey tea'],
#  'hitea': ['hitea'],
#  'holin': ['holin'],
#  'itea': ['itea'],
#  'jenjudan': ['jenjudan', 'jen ju dan'],
#  'liho': ['liho', 'li ho'],
#  'milksha': ['milksha'],
#  'playmade': ['playmade', 'play made'],
#  'sharetea': ['sharetea', 'share tea'],
#  'tiger sugar': ['tiger sugar', 'tiger sugar'],
#  'tptea': ['tptea', 'tp tea'],
#  'woobbee': ['woobbee'],
#  'xinfutang': ['xinfutang',
#   'xingfutang',
#   'xin fu tang',
#   'xing fu tang',
#   'xft']}

# %%
test = store_recognizer('bring me to itea', all_store_names, bbt_store_dict)
print(test)
# Out:
# itea

# %%
input_sentence = "should i upsize"

conv = tfidf_vectorizer.transform([input_sentence])
pred = intent_clf.predict(conv)

if pred == 0:
    print("dialouge")
elif pred == 1:
    print('Navigation')
else:
    print("Size")
# Out:
# Size

# %% [markdown]
# Pickle the RF Classifier as well as the vectorizer

# %% [markdown]
# Tea Shop Parser and Location Parser

# %%
# !ls
# Out:
# Intent_trainer.ipynb  common		   intent_rf.pkl    tfidf_trans.pkl
# README.md	      data		   main_bot.py	    utils.py
# __pycache__	      db.sqlite3	   movie_lines.tsv  week5-project.ipynb
# bbt_locations.csv     dialogue_manager.py  nav_int.txt
# bbt_store_list.txt    dialogues.tsv	   size_intent.txt

# %%
response.status_code == 200
# Out:
# True

# %%
1+1

# %%
import requests
import pandas as pd
import numpy as np

#input_postal = '760817'
#bbt_locations = pd.read_csv('bbt_locations.csv',  engine='python')
#brand = 'liho'

import requests

def get_coords(input_postal):
    response = requests.get('https://developers.onemap.sg/commonapi/search',
                            params={'searchVal':input_postal,
                                   'returnGeom':'Y',
                                   'getAddrDetails':'N'},
                            verify=False)

    json_response = response.json()

    if json_response['found'] >= 1:
        x_coord = float(json_response['results'][0]['X'])
        y_coord = float(json_response['results'][0]['Y'])

    else:
        x_coord = 30554.79254
        y_coord = 36683.05713
    
    return x_coord, y_coord

def calc_euclidean(coord1, coord2):
    return np.linalg.norm(np.array(coord1) - np.array(coord2), ord=2)

def calc_fastest_time(input_postal, brand, bbt_locations):
    x_coord, y_coord = get_coords(input_postal)
    #def get_nearest(input_postal, brand, bbt_locations):
    subframe = bbt_locations[bbt_locations['Brand'] == brand]
    dist_list_x = subframe['X'].values.tolist()
    dist_list_y = subframe['Y'].values.tolist()
    euclidean_list = []
    for candx,candy in zip(dist_list_x, dist_list_y):
        euclidean_list.append(calc_euclidean([x_coord, y_coord], [candx, candy]))

    subframe['distance'] = euclidean_list
    subframe.sort_values('distance', inplace=True)
    best_place = subframe.iloc[0]
    best_dist = best_place['distance']
    best_add = best_place['Location_Address']
    time_taken = best_dist/60.4
    
    return time_taken, best_add

a,b,c = calc_fastest_time(input_postal, brand, bbt_locations)
# Out:
# /usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
c
# Out:
#      Unnamed: 0   id Brand                        Location_Name  \
# 242         243  243  liho               LiHO @ Admiralty Place
# 207         208  208  liho                LiHO @ Jubilee Square
# 234         235  235  liho                   LiHO @ Greenwich V
# 225         226  226  liho                LiHO @ Ang Mo Kio Hub
# 218         219  219  liho         LiHO @ Woodlands MRT Xchange
# 208         209  209  liho                 LiHO @ Thomson Plaza
# 205         206  206  liho                     LiHO @ Hougang 1
# 209         210  210  liho                    LiHO @ Junction 8
# 245         246  246  liho                LiHO @ Waterway Point
# 219         220  220  liho                  LiHO @ Hougang Mall
# 206         207  207  liho                LiHO @ Rivervale Mall
# 215         216  216  liho           LiHO @ Bukit Panjang Plaza
# 216         217  217  liho                   LiHO @ Junction 10
# 199         200  200  liho                     LiHO @ Toa Payoh
# 240         241  241  liho      LiHO @ Zhongshan Mall Balestier
# 227         228  228  liho                 LiHO @ Yew Tee Point
# 223         224  224  liho                      LiHO @ Square 2
# 248         249  249  liho                   LiHO @ 18 Tai Seng
# 217         218  218  liho        LiHO @ Lot One Shoppers' Mall
# 198         199  199  liho               LiHO @ Goldhill Centre
# 197         198  198  liho                 LiHO @ United Square
# 184         185  185  liho              LiHO @ City Square Mall
# 192         193  193  liho                LiHO @ Far East Plaza
# 213         214  214  liho                     LiHO @ West Mall
# 214         215  215  liho                   LiHO @ Bukit Batok
# 246         247  247  liho                       LiHO @ Paragon
# 196         197  197  liho                   LiHO @ Wisma Atria
# 238         239  239  liho             LiHO @ Paya Lebar Square
# 210         211  211  liho                      LiHO @ Clementi
# 233         234  234  liho                        LiHO @ *SCAPE
# ..          ...  ...   ...                                  ...
# 244         245  245  liho                        LiHO @ One Km
# 200         201  201  liho                     LiHO @ Eunos MRT
# 211         212  212  liho                           LiHO @ IMM
# 193         194  194  liho              LiHO @ Great World City
# 247         248  248  liho              LiHO @ Suntec City Mall
# 190         191  191  liho  LiHO @ Raffles City Shopping Centre
# 237         238  238  liho                           LiHO @ JEM
# 221         222  222  liho                         LiHO @ JCube
# 224         225  225  liho                   LiHO @ The Central
# 203         204  204  liho                 LiHO @ Tampires Mall
# 189         190  190  liho                   LiHO @ Anchorpoint
# 204         205  205  liho                  LiHO @ Tampines MRT
# 188         189  189  liho              LiHO @ west Coast Plaza
# 201         202  202  liho                    LiHO @ 112 Katong
# 231         232  232  liho          LiHO @ China Square Central
# 229         230  230  liho                   LiHO @ Bukit Merah
# 241         242  242  liho                    LiHO @ Bedok Mall
# 232         233  233  liho              LiHO @ Marina Bay Sands
# 226         227  227  liho                   LiHO @ Bedok Point
# 236         237  237  liho           LiHO @ Asia Square Tower 2
# 185         186  186  liho     LiHO @ Tanjong Pagar MRT Xchange
# 186         187  187  liho                        LiHO @ 100 AM
# 202         203  203  liho                LiHO @ Eastpoint Mall
# 187         188  188  liho       LiHO @ Alexandra Retail Centre
# 212         213  213  liho         LiHO @ NTUC @ Jurong Point 1
# 222         223  223  liho                      LiHO @ VivoCity
# 230         231  231  liho       LiHO @ Gek Poh Shopping Centre
# 235         236  236  liho             LiHO @ Changi City Point
# 249         250  250  liho         LiHO @ Resorts World Sentosa
# 243         244  244  liho                 LiHO @ Fairprice Hub
#
#                                       Location_Address  Zipcodes  \
# 242  HDB Admiralty Place #01-15, 677 Woodlands Aven...    730677
# 207  Jubilee Square #01-14 , 61 Ang Mo Kio Avenue 8...    569814
# 234         Greenwich V #01-20, 1 Seletar Road, 807011    807011
# 225  Ang Mo Kio Hub #02-66, 53 Ang Mo Kio Avenue 3,...    569933
# 218  Woodlands MRT Station (NS9) #01-16, 30 Woodlan...    738343
# 208  Thomson Plaza #01-104, 301 Upper Thomson Road,...    574408
# 205      Hougang 1 #01-37, 1 Hougang Street 91, 538692    538692
# 209  Junction 8 Shopping Centre #02-18A, 9 Bishan P...    579837
# 245  Waterway Point (Shopping Centre) #B2-K10, 83 P...    828761
# 219  Hougang Mall #02-24, 90 Hougang Avenue 10, 538766    538766
# 206  Rivervale Mall #01-04A, 11 Rivervale Crescent,...    545082
# 215  Bukit Panjang Plaza #01-21, 1 Jelebu Road, 677743    677743
# 216       Junction 10 #01-26, 1 Woodlands Road, 677899    677899
# 199  HDB Toa Payoh Central #01-530, 184 Toa Payoh C...    310184
# 240  Zhongshan Mall Balestier #01-09, 20 Ah Hood Ro...    329984
# 227  Yew Tee Point #01-49/50, 21 Choa Chu Kang Nort...    689578
# 223         Square 2 #01-172, 10 Sinaran Drive, 307506    307506
# 248     18 Tai Seng #B1-11, 18 Tai Seng Street, 539775    539775
# 217  Lot One Shoppers' Mall #B1-K30, 21 Choa Chu Ka...    689812
# 198     Goldhill Centre #161, 151 Thomson Road, 307606    307606
# 197     United Square #B1-40, 101 Thomson Road, 307591    307591
# 184  City Square Mall #B2-K3/K4, 180 Kitchener Road...    208539
# 192     Far East Plaza #01-16F, 14 Scotts Road, 228213    228213
# 213  West Mall #B1-04/04A, 1 Bukit Batok Central Li...    658713
# 214  Bukit Batok MRT Station (NS2) #01-07, 10 Bukit...    659958
# 246  Paragon Shopping Centre #B1-39/40, 290 Orchard...    238859
# 196       Wisma Atria #B1-03, 435 Orchard Road, 238877    238877
# 238  Paya Lebar Square #01-50, 60 Paya Lebar Road, ...    409051
# 210      Clementi Arcade #01-87, 41 Sunset Way, 597071    597071
# 233              *SCAPE #02-10, 2 Orchard Link, 237978    237978
# ..                                                 ...       ...
# 244      Kinex #B1-K5 , 11 Tanjong Katong Road, 437157    437157
# 200  Eunos MRT Station (EW7) #01-05, 30 Eunos Cresc...    409423
# 211  IMM Building #01-K12, 2 Jurong East Street 21,...    609601
# 193  Great World City #B1-K1, 1 Kim Seng Promenade,...    237994
# 247  Suntec City Mall #03-379, 3 Temasek Boulevard,...     38983
# 190  Raffles City Shopping Centre #B1-71, 252 North...    179103
# 237  Jurong East Mall (JEM) #B1-30, 50 Jurong Gatew...    608549
# 221      JCube #02-77, 2 Jurong East Central 1, 609731    609731
# 224   The Central #B1-25, 6 Eu Tong Sen Street, 059817     59817
# 203  Tampines Mall #B1-K5, 4 Tampines Central 5, 52...    529510
# 189  Anchorpoint Shopping Centre #%u200EB1%u202C-47...    159953
# 204  Tampines MRT Station (EW2) #01-24, 20 Tampines...    529538
# 188  West Coast Plaza #B1-57, 154 West Coast Road, ...    127371
# 201    112 Katong #B1-02A, 112 East Coast Road, 428802    428802
# 231  China Square Central #01-56, 18 Cross Street, ...     48423
# 229  163 Bukit Merah Central Food Centre #01-3661, ...    150163
# 241  Bedok Mall #B2-K16, 311 New Upper Changi Road,...    467360
# 232  The Shoppes at Marina Bay Sands #01-72, 2 Bayf...     18972
# 226  Bedok Point #02-30, 799 New Upper Changi Road,...    467351
# 236  Asia Square Tower 2 #02-08, 12 Marina View, 01...     18961
# 185  Tanjong Pagar MRT Station (EW15) #B1-08, 120 M...     69119
# 186             100 AM #02-25, 100 Tras Street, 079027     79027
# 202  Eastpoint Mall (East Point) #01-K1, 3 Simei St...    528833
# 187  Alexandra Retail Centre (ARC) #01-10, 460 Alex...    119963
# 212  Jurong Point #B1-09, 1 Jurong West Central 2, ...    648886
# 222      VivoCity #01-111, 1 Harbourfront Walk, 098585     98585
# 230  Gek Poh Shopping Centre #01-328, 762 Jurong We...    640762
# 235  Changi City Point #B1-41, 5 Changi Business Pa...    486038
# 249  Resorts World at Sentosa #01-83 , 8 Sentosa Ga...     98269
# 243   Fairprice Hub #02-31 , 1 Joo Koon Circle, 629117    629117
#
#                                              SEARCHVAL            X  \
# 242                                    ADMIRALTY PLACE  24482.05904
# 207            61 ANG MO KIO AVENUE 8 SINGAPORE 569814  29608.90388
# 234                             MORIAH SCHOOLHOUSE LLP  31986.01400
# 225                                   DBS NTUC AMK HUB  29688.75118
# 218                        WOODLANDS MRT STATION (NS9)  22741.59819
# 208                                 DBS THOMSON BRANCH  27747.89951
# 205                             DBS NTUC HOUGANG POINT  33133.88460
# 209                         GOLDEN VILLAGE (GV BISHAN)  29718.54699
# 245                         OCBC WATERWAY POINT BRANCH  35657.70133
# 219                                       HOUGANG MALL  34722.37003
# 206             11 RIVERVALE CRESCENT SINGAPORE 545082  35919.73968
# 215                       BUKIT PANJANG PUBLIC LIBRARY  20351.92290
# 216                                    DBS JUNCTION 10  19887.22641
# 199                                  TOA PAYOH CENTRAL  29820.60173
# 240                                     ZHONGSHAN MALL  29473.00990
# 227                                       YEWTEE POINT  18344.71312
# 223                                           SQUARE 2  29225.62873
# 248                                        18 TAI SENG  34170.34542
# 217                       CHOA CHU KANG PUBLIC LIBRARY  18173.77105
# 198                           GOLDHILL SHOPPING CENTRE  29177.48471
# 197                                 EMBASSY OF FINLAND  29163.54939
# 184        MINDCHAMPS PRESCHOOL @ CITY SQUARE PTE. LTD  30578.43831
# 192                                     FAR EAST PLAZA  28038.54595
# 213                                      DBS WEST MALL  18630.07259
# 214                      BUKIT BATOK MRT STATION (NS2)  18679.35413
# 246                                    PARAGON MEDICAL  28291.84726
# 196                                        WISMA ATRIA  27985.64499
# 238                             OCBC PAYA LEBAR SQUARE  34595.30319
# 210                                    CLEMENTI ARCADE  20676.77294
# 233                                              SCAPE  28265.12421
# ..                                                 ...          ...
# 244                                              KINEX  34806.73779
# 200                            EUNOS MRT STATION (EW7)  35779.98898
# 211                     INTERNATIONAL MERCHANDISE MART  18381.92794
# 193              EMBASSY OF THE REPUBLIC OF KAZAKHSTAN  27836.84586
# 247                          CITIBANK SUNTEC CITY MALL  30808.32340
# 190                       RAFFLES CITY SHOPPING CENTRE  30203.71522
# 237                                CATHAY CINEPLEX JEM  17988.48383
# 221                                              JCUBE  17635.90426
# 224                                        THE CENTRAL  29473.21254
# 203                        UOB TAMPINES MALL AUTOLOBBY  40360.77460
# 189                                    DBS ANCHORPOINT  24885.21590
# 204                         TAMPINES MRT STATION (EW2)  40444.98461
# 188  MINDCHAMPS PRESCHOOL @ WEST COAST PLAZA PTE. L...  20492.29470
# 201                                     DBS 112 KATONG  35984.93090
# 231                                       PETRA CHURCH  29515.79085
# 229           163 BUKIT MERAH CENTRAL SINGAPORE 150163  26177.14879
# 241                                     UOB BEDOK MALL  38678.17140
# 232                             CRYSTAL PAVILION SOUTH  30705.56184
# 226                                        BEDOK POINT  39024.99022
# 236                                ASIA SQUARE TOWER 2  29945.00547
# 185                   TANJONG PAGAR MRT STATION (EW15)  29380.75674
# 186                                    AMARA SINGAPORE  29138.94500
# 202                                 DBS EASTPOINT BR 1  41324.89960
# 187                  CASINO REGULATORY AUTHORITY (CRA)  24443.65599
# 212                   UOB JURONG POINT SHOPPING CENTRE  13907.03050
# 222                   STANDARD CHARTERED BANK VIVOCITY  26774.67660
# 230                        DBS GEK POH SHOPPING CENTRE  12911.55971
# 235                                        CHANGI CITY  42409.14070
# 249                 ADVENTURE COVE WATERPARK SINGAPORE  26549.43664
# 243                           JOO KOON BUS INTERCHANGE  10745.68219
#
#                Y  LATITUDE   LONGITUDE  LONGTITUDE      distance
# 242  46785.54945  1.439386  103.801706  103.801706   4693.379250
# 207  39310.59346  1.371786  103.847776  103.847776   4710.039274
# 234  41036.67829  1.387395  103.869136  103.869136   4769.440208
# 225  39027.48929  1.369225  103.848493  103.848493   5003.733049
# 218  46501.78610  1.436820  103.786067  103.786067   5993.391179
# 208  37457.72240  1.355029  103.831053  103.831053   6313.686217
# 205  39739.86400  1.375667  103.879450  103.879450   6465.460045
# 209  36954.95700  1.350482  103.848761  103.848761   7004.222961
# 245  43144.64168  1.406458  103.902130  103.902130   7610.223132
# 219  39382.68690  1.372437  103.893724  103.893724   7962.815057
# 206  41601.66468  1.392504  103.904484  103.904484   8139.316489
# 215  40162.40475  1.379488  103.764595  103.764595   8519.050419
# 216  40239.11229  1.380182  103.760419  103.760419   8911.747258
# 199  34976.55532  1.332590  103.849678  103.849678   8958.675256
# 240  34352.36197  1.326945  103.846554  103.846554   9514.309973
# 227  42132.23986  1.397302  103.746558  103.746558   9863.682007
# 223  33652.15000  1.320613  103.844331  103.844331  10176.428444
# 248  35413.24278  1.336539  103.888763  103.888763  10339.305716
# 217  40765.18807  1.384939  103.745023  103.745023  10342.867497
# 198  33376.94229  1.318124  103.843899  103.843899  10444.708257
# 197  33272.41299  1.317178  103.843774  103.843774  10547.206455
# 184  32632.75939  1.311393  103.856487  103.856487  11408.873523
# 192  32174.22195  1.307247  103.833665  103.833665  11588.879589
# 213  36943.33091  1.350375  103.749124  103.749124  11647.779971
# 214  36795.01410  1.349034  103.749567  103.749567  11695.617728
# 246  31835.35160  1.304182  103.835941  103.835941  11929.713787
# 196  31781.91958  1.303699  103.833190  103.833190  11981.447664
# 238  33453.44350  1.318815  103.892581  103.892581  12199.716074
# 210  33977.36589  1.323553  103.767516  103.767516  12266.155773
# 233  31468.60909  1.300865  103.835701  103.835701  12295.948880
# ..           ...       ...         ...         ...           ...
# 244  32997.57752  1.314692  103.894481  103.894481  12698.166030
# 200  33560.58575  1.319784  103.903226  103.903226  12786.455403
# 211  35229.41215  1.334875  103.746895  103.746895  12912.513826
# 193  30644.29481  1.293411  103.831853  103.831853  13120.875556
# 247  30898.73000  1.295712  103.858553  103.858553  13151.984473
# 190  30697.70552  1.293894  103.853120  103.853120  13238.002815
# 237  35058.35681  1.333328  103.743359  103.743359  13321.487621
# 221  35048.38034  1.333238  103.740191  103.740191  13596.730035
# 224  30141.43606  1.288863  103.846556  103.846556  13693.428735
# 203  37197.43148  1.352672  103.944388  103.944388  13932.173951
# 189  30157.88889  1.289012  103.805331  103.805331  13973.552027
# 204  37267.01038  1.353302  103.945145  103.945145  13974.022800
# 188  31773.80099  1.303625  103.765858  103.765858  14184.634267
# 201  31943.41871  1.305158  103.905067  103.905067  14223.500618
# 231  29548.90868  1.283504  103.846939  103.846939  14287.215254
# 229  29590.58654  1.283881  103.816940  103.816940  14298.659683
# 241  34112.28879  1.324772  103.929268  103.929268  14339.260409
# 232  29528.81431  1.283322  103.857629  103.857629  14475.695179
# 226  34115.50370  1.324801  103.932384  103.932384  14595.513753
# 236  28974.25294  1.278307  103.850795  103.850795  14906.853769
# 185  28781.18833  1.276561  103.845725  103.845725  15038.862127
# 186  28601.32959  1.274935  103.843552  103.843552  15199.171065
# 202  36093.90160  1.342692  103.953051  103.953051  15311.371127
# 187  28462.46192  1.273679  103.801364  103.801364  15725.062971
# 212  35735.67771  1.339452  103.706685  103.706685  16281.995827
# 222  27425.92150  1.264305  103.822309  103.822309  16388.609970
# 230  36762.93500  1.348742  103.697740  103.697740  16699.106690
# 235  35145.34718  1.334113  103.962793  103.962793  16727.220573
# 249  26395.84396  1.254989  103.820285  103.820285  17433.876784
# 243  34376.87328  1.327162  103.678279  103.678279  19705.938476
#
# [66 rows x 13 columns]

# %%
def tea_shop_parser(input_sentence):
    return 'gongcha'  # String

def location_parser(input_sentence):
    return '570163'  # string of postal code

# %%
import os
os.makedirs(RESOURCE_PATH['THREAD_EMBEDDINGS_FOLDER'], exist_ok=True)

for tag, count in counts_by_tag.items():
    tag_posts = posts_df[posts_df['tag'] == tag]
    
    tag_post_ids = ######### YOUR CODE HERE #############
    
    tag_vectors = np.zeros((count, embeddings_dim), dtype=np.float32)
    for i, title in enumerate(tag_posts['title']):
        tag_vectors[i, :] = ######### YOUR CODE HERE #############

    # Dump post ids and vectors to a file.
    filename = os.path.join(RESOURCE_PATH['THREAD_EMBEDDINGS_FOLDER'], os.path.normpath('%s.pkl' % tag))
    pickle.dump((tag_post_ids, tag_vectors), open(filename, 'wb'))
